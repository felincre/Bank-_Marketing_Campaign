# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from operator import itemgetter
from sklearn.experimental import enable_iterative_imputer 
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import (GradientBoostingRegressor, GradientBoostingClassifier)
pd.set_option('display.max_columns', 500)
#import xgboost

# %matplotlib inline
sns.set()
plt.rc('xtick', labelsize=10)     
plt.rc('ytick', labelsize=10)

# %%
df = pd.read_csv("C:\\Users\\fcres\\OneDrive\\Documents\\DataGlacier\\proyecto_final\\data\\bank-additional-full.csv", sep=';')

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# ## Categorical columns

# %%
categorical_cols=['job', 'marital', 'education', 'default', 'housing', 'loan',
       'contact', 'month', 'day_of_week', 'poutcome']

for col in categorical_cols:# categories
  print(col,":")
  print(df[col].unique())
# Out:
# job :
# ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']
# marital :
# ['married' 'single' 'divorced' 'unknown']
# education :
# ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown' 'university.degree' 'illiterate']
# default :
# ['no' 'unknown' 'yes']
# housing :
# ['no' 'yes' 'unknown']
# loan :
# ['no' 'yes' 'unknown']
# contact :
# ['telephone' 'cellular']
# month :
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr' 'sep']
# day_of_week :
# ['mon' 'tue' 'wed' 'thu' 'fri']
# poutcome :
# ['nonexistent' 'failure' 'success']

# %% [markdown]
# ## Numerical columns

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# std        1.570960        0.578840       4.628198      1.734447     72.251528
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
numeric_col=df._get_numeric_data().columns
num_bank_df=df._get_numeric_data()

# %% [markdown]
# ## Target

# %%
print('"y" distribution in % : \n', (df.groupby("y")["y"].count())/df.y.count()*100)

print('"y" distribution in instances: \n', df.groupby("y")["y"].count())
# Out:
# "y" distribution in % :
#  y
# no     88.734583
# yes    11.265417
# Name: y, dtype: float64
# "y" distribution in instances:
#  y
# no     36548
# yes     4640
# Name: y, dtype: int64

# %%
y_perc=(df.groupby("y")["y"].count())/df.y.count()*100

# %%
labels=list(y_perc.index)
fig = plt.figure(figsize=(10,5)); ax = plt.axes()

ax.pie(y_perc ,labels=labels,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ## Outliers detection

# %%
num_cols = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(20, 20))

for i, col in enumerate(num_cols):
    sns.boxplot(data=df, x=col, ax=axes[i//2, i%2])
    axes[i//2, i%2].set_title(f"{col} boxplot")
    axes[i//2, i%2].set_xlabel(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the boxplots' interquartile ranges (IQR), we can identify that the variables "age", "duration", and "campaign" have outliers that need treatment. However, due to the assignment's statement, we will exclude "duration" from further analysis as it highly affects the output target.
#
# The boxplots for "pdays" and "previous" appear unusual, so we need to investigate them further.

# %%
df.drop("duration",inplace=True,axis=1)

# %% [markdown]
# ### Pdays

# %% [markdown]
# The "pdays" variable represents the number of days that have passed since the client was last contacted from a previous campaign. If the value is 999, it means the client was not previously contacted. It is a numeric variable.

# %%
ranges=[-1,5,10,15,20,25,30,1000]
labels=["0-5","6-10","11-15","16-20","21-25","26-30","No previous contacted"]

df["pdays_range"]=pd.cut(df.pdays,bins= ranges,labels=labels)

pdays_range_df=df.groupby("pdays_range")["campaign"].count()

pdays_range_df_per=pdays_range_df/(df.campaign.count())*100

print(pdays_range_df_per)
print(pdays_range_df)
# Out:
# pdays_range
# 0-5                       1.711664
# 6-10                      1.471302
# 11-15                     0.403030
# 16-20                     0.072837
# 21-25                     0.014567
# 26-30                     0.004856
# No previous contacted    96.321744
# Name: campaign, dtype: float64
# pdays_range
# 0-5                        705
# 6-10                       606
# 11-15                      166
# 16-20                       30
# 21-25                        6
# 26-30                        2
# No previous contacted    39673
# Name: campaign, dtype: int64

# %% [markdown]
# Since 96% of the clients were not previously contacted, we are not considering outliers in this feature. Therefore, we are treating the value of 999 as a legitimate value, rather than an outlier.

# %% [markdown]
# ### Previous

# %% [markdown]
# The "previous" variable represents the number of contacts performed before this campaign for the client. It is a numeric variable.

# %%
(df.groupby("previous")["campaign"].count())/df.campaign.count()*100
# Out:
# previous
# 0    86.343110
# 1    11.073614
# 2     1.830630
# 3     0.524425
# 4     0.169952
# 5     0.043702
# 6     0.012139
# 7     0.002428
# Name: campaign, dtype: float64

# %% [markdown]
# Since 97% of the clients have either 0 or 1 value for the "previous" variable, we are not considering outliers in this feature. This is because we want the model to learn how to treat customers who have been contacted before. Even though they are relatively few, they represent a real possibility that we want the model to be able to handle.

# %% [markdown]
# ### 1) IQR

# %%
def remove_outliers(dfx):
    q1 = dfx.quantile(0.25)
    q3 = dfx.quantile(0.75)
    iqr = q3 - q1
    cut_off = iqr*1.5
    
    df_filtred = dfx[~((dfx < (dfx.quantile(0.25) - cut_off)) | (dfx > (dfx.quantile(0.75) + cut_off))).any(axis=1)]
    
    
    return df_filtred

# %%
df_iqr = df.copy()

df_iqr = remove_outliers(df_iqr[['age','campaign']])

# %%
print(df.shape[0]-df_iqr.shape[0], 'rows have been eliminated')
# Out:
# 2861 rows have been eliminated

# %%
df_iqr.reset_index(drop=True, inplace=True)

# %%
plt.figure(figsize=(20, 20))
plt.subplot(2, 1, 1)
sns.boxplot(data=df_iqr, x='age')
plt.title('Age boxplot')
plt.xlabel('Age')

plt.subplot(2, 1, 2)
sns.boxplot(data=df_iqr, x='campaign')
plt.title('Campaign boxplot')
plt.xlabel('Campaign')
# Out:
# Text(0.5, 0, 'Campaign')

# %% [markdown]
# ### 2) WOE

# %%
def iv_woe(data, target, bins=10, show_woe=False):
    
    #Empty Dataframe
    newDF,woeDF = pd.DataFrame(), pd.DataFrame()
    
    #Extract Column Names
    cols = data.columns
    
    #Run WOE and IV on all the independent variables
    for ivars in cols[~cols.isin([target])]:
        if (data[ivars].dtype.kind in 'bifc') and (len(np.unique(data[ivars]))>10):
            binned_x = pd.qcut(data[ivars], bins,  duplicates='drop')
            d0 = pd.DataFrame({'x': binned_x, 'y': data[target]})
        else:
            d0 = pd.DataFrame({'x': data[ivars], 'y': data[target]})
        d = d0.groupby("x", as_index=False).agg({"y": ["count", "sum"]})
        d.columns = ['Cutoff', 'N', 'Events']
        d['% of Events'] = np.maximum(d['Events'], 0.5) / d['Events'].sum()
        d['Non-Events'] = d['N'] - d['Events']
        d['% of Non-Events'] = np.maximum(d['Non-Events'], 0.5) / d['Non-Events'].sum()
        d['WoE'] = np.log(d['% of Events']/d['% of Non-Events'])
        d['IV'] = d['WoE'] * (d['% of Events'] - d['% of Non-Events'])
        d.insert(loc=0, column='Variable', value=ivars)
        print("Information value of " + ivars + " is " + str(round(d['IV'].sum(),6)))
        temp =pd.DataFrame({"Variable" : [ivars], "IV" : [d['IV'].sum()]}, columns = ["Variable", "IV"])
        newDF=pd.concat([newDF,temp], axis=0)
        woeDF=pd.concat([woeDF,d], axis=0)

        #Show WOE Table
        if show_woe == True:
            print(d)
    return newDF, woeDF

# %%
df['y'].value_counts()
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %%
aux = df['y'] == 'no'
aux1 = df['y'] == 'yes'

# Convert
df.loc[aux, 'y'] = 0
df.loc[aux1, 'y'] = 1

print(df['y'].value_counts())
# Out:
# 0    36548
# 1     4640
# Name: y, dtype: int64

# %%
df['y'] = df['y'].astype(int)

print(df.dtypes)
# Out:
# age                  int64
# job                 object
# marital             object
# education           object
# default             object
# housing             object
# loan                object
# contact             object
# month               object
# day_of_week         object
# campaign             int64
# pdays                int64
# previous             int64
# poutcome            object
# emp.var.rate       float64
# cons.price.idx     float64
# cons.conf.idx      float64
# euribor3m          float64
# nr.employed        float64
# y                    int32
# pdays_range       category
# dtype: object

# %%
iv, woe = iv_woe(data = df, target = 'y', bins=10, show_woe = True)
# Out:
# Information value of age is 0.139397
#   Variable          Cutoff     N  Events  % of Events  Non-Events  \
# 0      age  (16.999, 28.0]  4216     736     0.158621        3480
# 1      age    (28.0, 31.0]  5114     608     0.131034        4506
# 2      age    (31.0, 33.0]  3679     394     0.084914        3285
# 3      age    (33.0, 35.0]  3504     351     0.075647        3153
# 4      age    (35.0, 38.0]  4662     434     0.093534        4228
# 5      age    (38.0, 41.0]  3871     311     0.067026        3560
# 6      age    (41.0, 45.0]  4311     348     0.075000        3963
# 7      age    (45.0, 49.0]  3776     289     0.062284        3487
# 8      age    (49.0, 55.0]  4473     428     0.092241        4045
# 9      age    (55.0, 98.0]  3582     741     0.159698        2841
#
#    % of Non-Events       WoE        IV
# 0         0.095217  0.510355  0.032358
# 1         0.123290  0.060922  0.000472
# 2         0.089882 -0.056859  0.000282
# 3         0.086270 -0.131411  0.001396
# 4         0.115683 -0.212528  0.004707
# 5         0.097406 -0.373811  0.011356
# 6         0.108433 -0.368642  0.012325
# 7         0.095409 -0.426458  0.014126
# 8         0.110676 -0.182202  0.003359
# 9         0.077733  0.720001  0.059015
# Information value of job is 0.188713
#    Variable         Cutoff      N  Events  % of Events  Non-Events  \
# 0       job         admin.  10422    1352     0.291379        9070
# 1       job    blue-collar   9254     638     0.137500        8616
# 2       job   entrepreneur   1456     124     0.026724        1332
# 3       job      housemaid   1060     106     0.022845         954
# 4       job     management   2924     328     0.070690        2596
# 5       job        retired   1720     434     0.093534        1286
# 6       job  self-employed   1421     149     0.032112        1272
# 7       job       services   3969     323     0.069612        3646
# 8       job        student    875     275     0.059267         600
# 9       job     technician   6743     730     0.157328        6013
# 10      job     unemployed   1014     144     0.031034         870
# 11      job        unknown    330      37     0.007974         293
#
#     % of Non-Events       WoE            IV
# 0          0.248167  0.160525  6.936681e-03
# 1          0.235745 -0.539126  5.296630e-02
# 2          0.036445 -0.310243  3.015900e-03
# 3          0.026103 -0.133312  4.343096e-04
# 4          0.071030 -0.004801  1.633538e-06
# 5          0.035187  0.977665  5.704466e-02
# 6          0.034804 -0.080487  2.166298e-04
# 7          0.099759 -0.359822  1.084759e-02
# 8          0.016417  1.283754  5.500945e-02
# 9          0.164523 -0.044722  3.218128e-04
# 10         0.023804  0.265232  1.917674e-03
# 11         0.008017 -0.005343  2.282177e-07
# Information value of marital is 0.028215
#   Variable    Cutoff      N  Events  % of Events  Non-Events  % of Non-Events  \
# 0  marital  divorced   4612     476     0.102586        4136         0.113166
# 1  marital   married  24928    2532     0.545690       22396         0.612783
# 2  marital    single  11568    1620     0.349138        9948         0.272190
# 3  marital   unknown     80      12     0.002586          68         0.001861
#
#         WoE        IV
# 0 -0.098154  0.001038
# 1 -0.115961  0.007780
# 2  0.248967  0.019157
# 3  0.329311  0.000239
# Information value of education is 0.048576
#     Variable               Cutoff      N  Events  % of Events  Non-Events  \
# 0  education             basic.4y   4176     428     0.092241        3748
# 1  education             basic.6y   2292     188     0.040517        2104
# 2  education             basic.9y   6045     473     0.101940        5572
# 3  education          high.school   9515    1031     0.222198        8484
# 4  education           illiterate     18       4     0.000862          14
# 5  education  professional.course   5243     595     0.128233        4648
# 6  education    university.degree  12168    1670     0.359914       10498
# 7  education              unknown   1731     251     0.054095        1480
#
#    % of Non-Events       WoE        IV
# 0         0.102550 -0.105942  0.001092
# 1         0.057568 -0.351242  0.005989
# 2         0.152457 -0.402502  0.020333
# 3         0.232133 -0.043741  0.000435
# 4         0.000383  0.811149  0.000389
# 5         0.127175  0.008281  0.000009
# 6         0.287239  0.225551  0.016392
# 7         0.040495  0.289568  0.003938
# Information value of default is 0.127776
#   Variable   Cutoff      N  Events  % of Events  Non-Events  % of Non-Events  \
# 0  default       no  32588    4197     0.904526       28391         0.776814
# 1  default  unknown   8597     443     0.095474        8154         0.223104
# 2  default      yes      3       0     0.000108           3         0.000082
#
#         WoE        IV
# 0  0.152210  0.019439
# 1 -0.848782  0.108330
# 2  0.272153  0.000007
# Information value of housing is 0.001383
#   Variable   Cutoff      N  Events  % of Events  Non-Events  % of Non-Events  \
# 0  housing       no  18622    2026     0.436638       16596         0.454088
# 1  housing  unknown    990     107     0.023060         883         0.024160
# 2  housing      yes  21576    2507     0.540302       19069         0.521752
#
#         WoE        IV
# 0 -0.039186  0.000684
# 1 -0.046584  0.000051
# 2  0.034935  0.000648
# Information value of loan is 0.000269
#   Variable   Cutoff      N  Events  % of Events  Non-Events  % of Non-Events  \
# 0     loan       no  33950    3850     0.829741       30100         0.823574
# 1     loan  unknown    990     107     0.023060         883         0.024160
# 2     loan      yes   6248     683     0.147198        5565         0.152266
#
#         WoE        IV
# 0  0.007460  0.000046
# 1 -0.046584  0.000051
# 2 -0.033845  0.000172
# Information value of contact is 0.251663
#   Variable     Cutoff      N  Events  % of Events  Non-Events  \
# 0  contact   cellular  26144    3853     0.830388       22291
# 1  contact  telephone  15044     787     0.169612       14257
#
#    % of Non-Events       WoE        IV
# 0          0.60991  0.308581  0.068035
# 1          0.39009 -0.832863  0.183628
# Information value of month is 0.485117
#   Variable Cutoff      N  Events  % of Events  Non-Events  % of Non-Events  \
# 0    month    apr   2632     539     0.116164        2093         0.057267
# 1    month    aug   6178     655     0.141164        5523         0.151116
# 2    month    dec    182      89     0.019181          93         0.002545
# 3    month    jul   7174     649     0.139871        6525         0.178532
# 4    month    jun   5318     559     0.120474        4759         0.130212
# 5    month    mar    546     276     0.059483         270         0.007388
# 6    month    may  13769     886     0.190948       12883         0.352495
# 7    month    nov   4101     416     0.089655        3685         0.100826
# 8    month    oct    718     315     0.067888         403         0.011027
# 9    month    sep    570     256     0.055172         314         0.008591
#
#         WoE        IV
# 0  0.707274  0.041656
# 1 -0.068129  0.000678
# 2  2.019949  0.033605
# 3 -0.244051  0.009435
# 4 -0.077731  0.000757
# 5  2.085891  0.108665
# 6 -0.613035  0.099034
# 7 -0.117428  0.001312
# 8  1.817548  0.103348
# 9  1.859697  0.086626
# Information value of day_of_week is 0.006493
#       Variable Cutoff     N  Events  % of Events  Non-Events  % of Non-Events  \
# 0  day_of_week    fri  7827     846     0.182328        6981         0.191009
# 1  day_of_week    mon  8514     847     0.182543        7667         0.209779
# 2  day_of_week    thu  8623    1045     0.225216        7578         0.207344
# 3  day_of_week    tue  8090     953     0.205388        7137         0.195277
# 4  day_of_week    wed  8134     949     0.204526        7185         0.196591
#
#         WoE        IV
# 0 -0.046516  0.000404
# 1 -0.139068  0.003788
# 2  0.082680  0.001478
# 3  0.050479  0.000510
# 4  0.039570  0.000314
# Information value of campaign is 0.054246
#    Variable        Cutoff      N  Events  % of Events  Non-Events  \
# 0  campaign  (0.999, 2.0]  28212    3511     0.756681       24701
# 1  campaign    (2.0, 3.0]   5341     574     0.123707        4767
# 2  campaign    (3.0, 5.0]   4250     369     0.079526        3881
# 3  campaign   (5.0, 56.0]   3385     186     0.040086        3199
#
#    % of Non-Events       WoE        IV
# 0         0.675851  0.112969  0.009131
# 1         0.130431 -0.052931  0.000356
# 2         0.106189 -0.289139  0.007709
# 3         0.087529 -0.780935  0.037050
# Information value of pdays is 0.0
#   Variable           Cutoff      N  Events  % of Events  Non-Events  \
# 0    pdays  (-0.001, 999.0]  41188    4640          1.0       36548
#
#    % of Non-Events  WoE   IV
# 0              1.0  0.0  0.0
# Information value of previous is 0.3505
#    Variable  Cutoff      N  Events  % of Events  Non-Events  % of Non-Events  \
# 0  previous       0  35563    3141     0.676940       32422         0.887107
# 1  previous       1   4561     967     0.208405        3594         0.098336
# 2  previous       2    754     350     0.075431         404         0.011054
# 3  previous       3    216     128     0.027586          88         0.002408
# 4  previous       4     70      38     0.008190          32         0.000876
# 5  previous       5     18      13     0.002802           5         0.000137
# 6  previous       6      5       3     0.000647           2         0.000055
# 7  previous       7      1       0     0.000108           1         0.000027
#
#         WoE        IV
# 0 -0.270384  0.056826
# 1  0.751090  0.082671
# 2  1.920430  0.123632
# 3  2.438606  0.061400
# 4  2.235762  0.016353
# 5  3.019424  0.008047
# 6  2.469377  0.001461
# 7  1.370765  0.000110
# Information value of poutcome is 0.547671
#    Variable       Cutoff      N  Events  % of Events  Non-Events  \
# 0  poutcome      failure   4252     605     0.130388        3647
# 1  poutcome  nonexistent  35563    3141     0.676940       32422
# 2  poutcome      success   1373     894     0.192672         479
#
#    % of Non-Events       WoE        IV
# 0         0.099787  0.267480  0.008185
# 1         0.887107 -0.270384  0.056826
# 2         0.013106  2.687917  0.482660
# Information value of emp.var.rate is 1.06975
#        Variable  Cutoff      N  Events  % of Events  Non-Events  \
# 0  emp.var.rate    -3.4   1071     454     0.097845         617
# 1  emp.var.rate    -3.0    172      88     0.018966          84
# 2  emp.var.rate    -2.9   1663     594     0.128017        1069
# 3  emp.var.rate    -1.8   9184    1461     0.314871        7723
# 4  emp.var.rate    -1.7    773     403     0.086853         370
# 5  emp.var.rate    -1.1    635     301     0.064871         334
# 6  emp.var.rate    -0.2     10       1     0.000216           9
# 7  emp.var.rate    -0.1   3683     232     0.050000        3451
# 8  emp.var.rate     1.1   7763     240     0.051724        7523
# 9  emp.var.rate     1.4  16234     866     0.186638       15368
#
#    % of Non-Events       WoE        IV
# 0         0.016882  1.757140  0.142263
# 1         0.002298  2.110432  0.035175
# 2         0.029249  1.476313  0.145812
# 3         0.211311  0.398830  0.041303
# 4         0.010124  2.149346  0.164919
# 5         0.009139  1.959881  0.109228
# 6         0.000246 -0.133312  0.000004
# 7         0.094424 -0.635770  0.028243
# 8         0.205839 -1.381169  0.212859
# 9         0.420488 -0.812246  0.189944
# Information value of cons.price.idx is 0.440236
#          Variable                       Cutoff     N  Events  % of Events  \
# 0  cons.price.idx  (92.19999999999999, 92.893]  8277    1523     0.328233
# 1  cons.price.idx               (92.893, 93.2]  6789     896     0.193103
# 2  cons.price.idx               (93.2, 93.444]  5439     421     0.090733
# 3  cons.price.idx             (93.444, 93.749]   174      97     0.020905
# 4  cons.price.idx             (93.749, 93.918]  6964     571     0.123060
# 5  cons.price.idx             (93.918, 93.994]  7763     240     0.051724
# 6  cons.price.idx             (93.994, 94.465]  5450     741     0.159698
# 7  cons.price.idx             (94.465, 94.767]   332     151     0.032543
#
#    Non-Events  % of Non-Events       WoE        IV
# 0        6754         0.184798  0.574459  0.082397
# 1        5893         0.161240  0.180332  0.005746
# 2        5018         0.137299 -0.414242  0.019290
# 3          77         0.002107  2.294818  0.043139
# 4        6393         0.174921 -0.351658  0.018237
# 5        7523         0.205839 -1.381169  0.212859
# 6        4709         0.128844  0.214682  0.006624
# 7         181         0.004952  1.882695  0.051945
# Information value of cons.conf.idx is 0.86074
#         Variable                        Cutoff     N  Events  % of Events  \
# 0  cons.conf.idx  (-50.800999999999995, -46.2]  8866    1243     0.267888
# 1  cons.conf.idx                (-46.2, -42.7]  6695     408     0.087931
# 2  cons.conf.idx                (-42.7, -42.0]  3616     190     0.040948
# 3  cons.conf.idx                (-42.0, -41.8]  4374     188     0.040517
# 4  cons.conf.idx                (-41.8, -40.0]  1305     604     0.130172
# 5  cons.conf.idx                (-40.0, -36.4]  8528     617     0.132974
# 6  cons.conf.idx                (-36.4, -36.1]  5175     271     0.058405
# 7  cons.conf.idx                (-36.1, -26.9]  2629    1119     0.241164
#
#    Non-Events  % of Non-Events       WoE        IV
# 0        7623         0.208575  0.250270  0.014844
# 1        6287         0.172020 -0.671060  0.056429
# 2        3426         0.093740 -0.828213  0.043723
# 3        4186         0.114534 -1.039147  0.076915
# 4         701         0.019180  1.914978  0.212548
# 5        7911         0.216455 -0.487228  0.040674
# 6        4904         0.134180 -0.831776  0.063027
# 7        1510         0.041316  1.764238  0.352580
# Information value of euribor3m is 1.046047
#     Variable          Cutoff     N  Events  % of Events  Non-Events  \
# 0  euribor3m  (0.633, 1.046]  4128    1895     0.408405        2233
# 1  euribor3m  (1.046, 1.299]  4508     666     0.143534        3842
# 2  euribor3m   (1.299, 1.41]  3926     494     0.106466        3432
# 3  euribor3m   (1.41, 4.191]  4504     415     0.089440        4089
# 4  euribor3m  (4.191, 4.857]  4989     156     0.033621        4833
# 5  euribor3m  (4.857, 4.864]  3457     150     0.032328        3307
# 6  euribor3m   (4.864, 4.96]  3983     235     0.050647        3748
# 7  euribor3m   (4.96, 4.962]  4515     234     0.050431        4281
# 8  euribor3m  (4.962, 4.964]  3662     181     0.039009        3481
# 9  euribor3m  (4.964, 5.045]  3516     214     0.046121        3302
#
#    % of Non-Events       WoE        IV
# 0         0.061098  1.899785  0.659809
# 1         0.105122  0.311453  0.011964
# 2         0.093904  0.125549  0.001577
# 3         0.111880 -0.223865  0.005024
# 4         0.132237 -1.369455  0.135051
# 5         0.090484 -1.029249  0.059857
# 6         0.102550 -0.705480  0.036617
# 7         0.117134 -0.842709  0.056211
# 8         0.095245 -0.892666  0.050200
# 9         0.090347 -0.672396  0.029738
# Information value of nr.employed is 1.173723
#       Variable              Cutoff      N  Events  % of Events  Non-Events  \
# 0  nr.employed  (4963.599, 5076.2]   4964    2209     0.476078        2755
# 1  nr.employed    (5076.2, 5099.1]   8534    1092     0.235345        7442
# 2  nr.employed    (5099.1, 5191.0]   7773     241     0.051940        7532
# 3  nr.employed    (5191.0, 5195.8]   3683     232     0.050000        3451
# 4  nr.employed    (5195.8, 5228.1]  16234     866     0.186638       15368
#
#    % of Non-Events       WoE        IV
# 0         0.075380  1.843035  0.738499
# 1         0.203623  0.144783  0.004593
# 2         0.206085 -1.378207  0.212444
# 3         0.094424 -0.635770  0.028243
# 4         0.420488 -0.812246  0.189944
# Information value of pdays_range is 0.554801
#       Variable                 Cutoff      N  Events  % of Events  Non-Events  \
# 0  pdays_range                    0-5    705     445     0.095905         260
# 1  pdays_range                   6-10    606     406     0.087500         200
# 2  pdays_range                  11-15    166      96     0.020690          70
# 3  pdays_range                  16-20     30      13     0.002802          17
# 4  pdays_range                  21-25      6       5     0.001078           1
# 5  pdays_range                  26-30      2       2     0.000431           0
# 6  pdays_range  No previous contacted  39673    3673     0.791595       36000
#
#    % of Non-Events       WoE        IV
# 0         0.007114  2.601305  0.230973
# 1         0.005472  2.771948  0.227377
# 2         0.001915  2.379765  0.044679
# 3         0.000465  1.795648  0.004196
# 4         0.000027  3.673350  0.003858
# 5         0.000014  3.450206  0.001440
# 6         0.985006 -0.218598  0.042279

# %%
print(iv)
# Out:
#          Variable        IV
# 0             age  0.139397
# 0             job  0.188713
# 0         marital  0.028215
# 0       education  0.048576
# 0         default  0.127776
# 0         housing  0.001383
# 0            loan  0.000269
# 0         contact  0.251663
# 0           month  0.485117
# 0     day_of_week  0.006493
# 0        campaign  0.054246
# 0           pdays  0.000000
# 0        previous  0.350500
# 0        poutcome  0.547671
# 0    emp.var.rate  1.069750
# 0  cons.price.idx  0.440236
# 0   cons.conf.idx  0.860740
# 0       euribor3m  1.046047
# 0     nr.employed  1.173723
# 0     pdays_range  0.554801

# %% [markdown]
# ### Information Value
#
# | Predictive Power | IV |
# | --- | --- |
# | Useless for prediction | <0.02 |
# | Weak predictor | 0.02 to 0.1 |
# | Medium predictor | 0.1 to 0.3 |
# | Strong predictor | 0.3 to 0.5 |
# | Suspicious or too good predictor | > 0.5 |
#
# Based on the IV values calculated for each feature, we can classify them into different categories of predictive power:
#
# | Variable        | IV        | Predictive Power |
# |-----------------|-----------|-----------------|
# | loan            | 0.000269  | Useless         |
# | pdays           | 0.000000  | Useless         |
# | housing         | 0.001383  | Useless         |
# | day_of_week     | 0.006493  | Useless         |
# | marital         | 0.028215  | Weak            |
# | education       | 0.048576  | Weak            |
# | campaign        | 0.054246  | Weak            |
# | default         | 0.127776  | Weak            |
# | age             | 0.139397  | Medium          |
# | poutcome        | 0.547671  | Strong          |
# | pdays_range     | 0.554801  | Strong          |
# | previous        | 0.350500  | Medium          |
# | cons.price.idx  | 0.440236  | Strong          |
# | job             | 0.188713  | Medium          |
# | contact         | 0.251663  | Medium          |
# | cons.conf.idx   | 0.860740  | Suspicious      |
# | emp.var.rate    | 1.069750  | Suspicious      |
# | euribor3m       | 1.046047  | Suspicious      |
# | nr.employed     | 1.173723  | Suspicious      |
# | month           | 0.485117  | Strong          |

# %% [markdown]
# ### Replacement with WOE values
# As we said before, we will treat "age" and "campaign".

# %%
df_woe= df.copy()

# %%
age= pd.DataFrame(df_woe['age'])
age.columns = ['age']
age, age.columns
# Out:
# (       age
#  0       56
#  1       57
#  2       37
#  3       40
#  4       56
#  ...    ...
#  41183   73
#  41184   46
#  41185   56
#  41186   44
#  41187   74
#
#  [41188 rows x 1 columns],
#  Index(['age'], dtype='object'))

# %%
age_table = woe[:10]
age_table
# Out:
#   Variable          Cutoff     N  Events  % of Events  Non-Events  \
# 0      age  (16.999, 28.0]  4216     736     0.158621        3480
# 1      age    (28.0, 31.0]  5114     608     0.131034        4506
# 2      age    (31.0, 33.0]  3679     394     0.084914        3285
# 3      age    (33.0, 35.0]  3504     351     0.075647        3153
# 4      age    (35.0, 38.0]  4662     434     0.093534        4228
# 5      age    (38.0, 41.0]  3871     311     0.067026        3560
# 6      age    (41.0, 45.0]  4311     348     0.075000        3963
# 7      age    (45.0, 49.0]  3776     289     0.062284        3487
# 8      age    (49.0, 55.0]  4473     428     0.092241        4045
# 9      age    (55.0, 98.0]  3582     741     0.159698        2841
#
#    % of Non-Events       WoE        IV
# 0         0.095217  0.510355  0.032358
# 1         0.123290  0.060922  0.000472
# 2         0.089882 -0.056859  0.000282
# 3         0.086270 -0.131411  0.001396
# 4         0.115683 -0.212528  0.004707
# 5         0.097406 -0.373811  0.011356
# 6         0.108433 -0.368642  0.012325
# 7         0.095409 -0.426458  0.014126
# 8         0.110676 -0.182202  0.003359
# 9         0.077733  0.720001  0.059015

# %%
#CREATE STRUCTURE TO EXTRACT LIMITS
idx = pd.IntervalIndex(age_table['Cutoff'])

#INTERVALS , LIMITS AND WOE VALUES
inter = pd.DataFrame({'intervals': idx, 'left': idx.left, 'right': idx.right})
inter['WOE'] = age_table['WoE']
inter
# Out:
#         intervals    left  right       WOE
# 0  (16.999, 28.0]  16.999   28.0  0.510355
# 1    (28.0, 31.0]  28.000   31.0  0.060922
# 2    (31.0, 33.0]  31.000   33.0 -0.056859
# 3    (33.0, 35.0]  33.000   35.0 -0.131411
# 4    (35.0, 38.0]  35.000   38.0 -0.212528
# 5    (38.0, 41.0]  38.000   41.0 -0.373811
# 6    (41.0, 45.0]  41.000   45.0 -0.368642
# 7    (45.0, 49.0]  45.000   49.0 -0.426458
# 8    (49.0, 55.0]  49.000   55.0 -0.182202
# 9    (55.0, 98.0]  55.000   98.0  0.720001

# %%
#CREATE AUXILIARY VARIABLES
inter['left'][0],inter['right'][0]

aux1 = (inter['left'][0] <=  age) & (age < inter['right'][0])
aux2 = (inter['left'][1] <=  age) & (age < inter['right'][1])
aux3 = (inter['left'][2] <=  age) & (age < inter['right'][2])
aux4 = (inter['left'][3] <=  age) & (age < inter['right'][3])
aux5 = (inter['left'][4] <=  age) & (age < inter['right'][4])
aux6 = (inter['left'][5] <=  age) & (age < inter['right'][5])
aux7 = (inter['left'][6] <=  age) & (age < inter['right'][6])
aux8 = (inter['left'][7] <=  age) & (age < inter['right'][7])
aux9 = (inter['left'][8] <=  age) & (age < inter['right'][8])
aux10 = (inter['left'][9] <=  age) & (age <= inter['right'][9])

# %%
#REPLACE VALUES WITH WOE
age[aux1] = inter['WOE'][0]
age[aux2] = inter['WOE'][1]
age[aux3] = inter['WOE'][2]
age[aux4] = inter['WOE'][3]
age[aux5] = inter['WOE'][4]
age[aux6] = inter['WOE'][5]
age[aux7] = inter['WOE'][6]
age[aux8] = inter['WOE'][7]
age[aux9] = inter['WOE'][8]
age[aux10] = inter['WOE'][9]

age.value_counts()
# Out:
# age
# -0.212528    5014
# -0.182202    4664
# -0.368642    4486
#  0.720001    4230
#  0.060922    4168
# -0.426458    4040
# -0.373811    4000
# -0.056859    3793
# -0.131411    3578
#  0.510355    3215
# dtype: int64

# %%
df_woe['age'] = age
df_woe['age'].value_counts()
# Out:
# -0.212528    5014
# -0.182202    4664
# -0.368642    4486
#  0.720001    4230
#  0.060922    4168
# -0.426458    4040
# -0.373811    4000
# -0.056859    3793
# -0.131411    3578
#  0.510355    3215
# Name: age, dtype: int64

# %%
campaign= pd.DataFrame(df_woe['campaign'])
campaign.columns = ['campaign']
campaign['campaign'].value_counts()
# Out:
# 1     17642
# 2     10570
# 3      5341
# 4      2651
# 5      1599
# 6       979
# 7       629
# 8       400
# 9       283
# 10      225
# 11      177
# 12      125
# 13       92
# 14       69
# 17       58
# 16       51
# 15       51
# 18       33
# 20       30
# 19       26
# 21       24
# 22       17
# 23       16
# 24       15
# 27       11
# 29       10
# 28        8
# 26        8
# 25        8
# 31        7
# 30        7
# 35        5
# 32        4
# 33        4
# 34        3
# 42        2
# 40        2
# 43        2
# 56        1
# 39        1
# 41        1
# 37        1
# Name: campaign, dtype: int64

# %%
#SELECT VALUES FOR CAMPAIGN VARIABLE
aux_c = woe['Variable'] == 'campaign' 
campaign_table = woe[aux_c]
campaign_table
# Out:
#    Variable        Cutoff      N  Events  % of Events  Non-Events  \
# 0  campaign  (0.999, 2.0]  28212    3511     0.756681       24701
# 1  campaign    (2.0, 3.0]   5341     574     0.123707        4767
# 2  campaign    (3.0, 5.0]   4250     369     0.079526        3881
# 3  campaign   (5.0, 56.0]   3385     186     0.040086        3199
#
#    % of Non-Events       WoE        IV
# 0         0.675851  0.112969  0.009131
# 1         0.130431 -0.052931  0.000356
# 2         0.106189 -0.289139  0.007709
# 3         0.087529 -0.780935  0.037050

# %%
#CREATE STRUCTURE TO EXTRACT LIMITS
idx = pd.IntervalIndex(campaign_table['Cutoff'])

#INTERVALS , LIMITS AND WOE VALUES
inter = pd.DataFrame({'intervals': idx, 'left': idx.left, 'right': idx.right})
inter['WOE'] = campaign_table['WoE']
inter
# Out:
#       intervals   left  right       WOE
# 0  (0.999, 2.0]  0.999    2.0  0.112969
# 1    (2.0, 3.0]  2.000    3.0 -0.052931
# 2    (3.0, 5.0]  3.000    5.0 -0.289139
# 3   (5.0, 56.0]  5.000   56.0 -0.780935

# %%
#CREATE AUXILIARY VARIABLES
inter['left'][0],inter['right'][0]

aux1 = (inter['left'][0] <=  campaign) & (campaign < inter['right'][0])
aux2 = (inter['left'][1] <=  campaign) & (campaign < inter['right'][1])
aux3 = (inter['left'][2] <=  campaign) & (campaign < inter['right'][2])
aux4 = (inter['left'][3] <=  campaign) & (campaign <= inter['right'][3])

# %%
#REPLACE VALUES WITH WOE
campaign[aux1] = inter['WOE'][0]
campaign[aux2] = inter['WOE'][1]
campaign[aux3] = inter['WOE'][2]
campaign[aux4] = inter['WOE'][3]

campaign.value_counts()
# Out:
# campaign
#  0.112969    17642
# -0.052931    10570
# -0.289139     7992
# -0.780935     4984
# dtype: int64

# %%
#REPLACE OLD VARIABLE
df_woe['campaign'] = campaign
df_woe['campaign'].value_counts()
# Out:
#  0.112969    17642
# -0.052931    10570
# -0.289139     7992
# -0.780935     4984
# Name: campaign, dtype: int64

# %%
df_woe.head(3)
# Out:
#         age        job  marital    education  default housing loan    contact  \
# 0  0.720001  housemaid  married     basic.4y       no      no   no  telephone
# 1  0.720001   services  married  high.school  unknown      no   no  telephone
# 2 -0.212528   services  married  high.school       no     yes   no  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon  0.112969    999         0  nonexistent           1.1
# 1   may         mon  0.112969    999         0  nonexistent           1.1
# 2   may         mon  0.112969    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y  \
# 0          93.994          -36.4      4.857       5191.0  0
# 1          93.994          -36.4      4.857       5191.0  0
# 2          93.994          -36.4      4.857       5191.0  0
#
#              pdays_range
# 0  No previous contacted
# 1  No previous contacted
# 2  No previous contacted

# %%
df_woe.shape
# Out:
# (41188, 21)

# %% [markdown]
# From here, we continue with bank_df_woe as our dataframe for modeling

# %%
df = df_woe.copy()

# %%
num_cols = ['age', 'campaign']

fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(20, 20))

for i, col in enumerate(num_cols):
    sns.boxplot(data=df, x=col, ax=axes[i//2, i%2])
    axes[i//2, i%2].set_title(f"{col} boxplot")
    axes[i//2, i%2].set_xlabel(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Skew

# %%
df.skew()
# Out:
# age               1.149065
# campaign         -1.319181
# pdays            -4.922190
# previous          3.832042
# emp.var.rate     -0.724096
# cons.price.idx   -0.230888
# cons.conf.idx     0.303180
# euribor3m        -0.709188
# nr.employed      -1.044262
# y                 2.450330
# dtype: float64

# %%
df_woe['pdays'] = np.sqrt(df_woe['pdays'])
df_woe['previous'] = np.sqrt(df_woe['previous'])

# %%
df_woe.skew()
# Out:
# age               1.149065
# campaign         -1.319181
# pdays            -4.927351
# previous          2.388752
# emp.var.rate     -0.724096
# cons.price.idx   -0.230888
# cons.conf.idx     0.303180
# euribor3m        -0.709188
# nr.employed      -1.044262
# y                 2.450330
# dtype: float64

# %% [markdown]
# The square root function has no effect on the variable 'pdays' due to its values being very high, close to the maximum value of the data type used to store the values.

# %% [markdown]
# ### Missing Values
#
# The dataset contains missing values represented by the string "unknown". Before proceeding with any analysis, we need to handle these missing values appropriately. One way to do this is by replacing the string "unknown" with a NaN value using NumPy's np.NaN function.
#
# After replacing the missing values with NaN, we can consider different approaches to handle them, such as imputing the missing values or deleting them.

# %%
df= df.replace(to_replace="unknown" ,value=np.NaN,regex=True)

# %%
print(df.isnull().sum())

null_columns=["job","marital","education","default","housing","loan"]
# Out:
# age                  0
# job                330
# marital             80
# education         1731
# default           8597
# housing            990
# loan               990
# contact              0
# month                0
# day_of_week          0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx       0
# cons.conf.idx        0
# euribor3m            0
# nr.employed          0
# y                    0
# pdays_range          0
# dtype: int64

# %%
nulls=df[null_columns].isnull().sum()
print("Q of nulls: ")
print(nulls)

print("% of nulls: ")
print(nulls/df.shape[0]*100)
# Out:
# Q of nulls:
# job           330
# marital        80
# education    1731
# default      8597
# housing       990
# loan          990
# dtype: int64
# % of nulls:
# job           0.801204
# marital       0.194231
# education     4.202680
# default      20.872584
# housing       2.403613
# loan          2.403613
# dtype: float64

# %%
nulls.plot.bar()

plt.title('Null values', fontsize=20)
plt.ylabel('Q of nulls')
plt.xlabel('Features')
# Out:
# Text(0.5, 0, 'Features')

# %% [markdown]
# In order ot be more sure what is the best option of missing values treatment for the model, we are going to analyse a little bit deeper the features with null values.
#
# First "default", the feature with most nulls. It has 20.9% of missing values.

# %%
print("Value Distribution: ")
print(df.default.value_counts())

print("Value Distribution %: ")
print(df.default.value_counts()/df.default.notnull().sum()*100)
# Out:
# Value Distribution:
# no     32588
# yes        3
# Name: default, dtype: int64
# Value Distribution %:
# no     99.990795
# yes     0.009205
# Name: default, dtype: float64

# %% [markdown]
# On one hand, the "default" feature has a significant number of missing values (20.9%), making imputation a risky option that could introduce bias into the model. To create a realistic and useful model, it would be best to avoid imputation for this feature.
#
# On the other hand, this feature is highly unbalanced, with only 0.009% of clients having a non-null value of "1" for default. Additionally, the feature's Information Value (IV) is 0.128, indicating that it is a medium predictor.
#
# Taken together, these factors suggest that the best option may be to simply delete the "default" feature. However, we will still explore the impact of both deleting the feature and imputing missing values using KNNImputer (for "loan", "housing", and "default") on the model.

# %% [markdown]
# ## 1) KNN Imputation

# %%
knn_df=df.copy()

# %%
df.isnull().sum()
# Out:
# age                  0
# job                330
# marital             80
# education         1731
# default           8597
# housing            990
# loan               990
# contact              0
# month                0
# day_of_week          0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx       0
# cons.conf.idx        0
# euribor3m            0
# nr.employed          0
# y                    0
# pdays_range          0
# dtype: int64

# %%
aux = knn_df['default'] == 'no'
aux1 = knn_df['default'] == 'yes'

# Convert
knn_df.loc[aux, 'default'] = 0
knn_df.loc[aux1, 'default'] = 1

aux = knn_df['housing'] == 'no'
aux1 = knn_df['housing'] == 'yes'

# Convert
knn_df.loc[aux, 'housing'] = 0
knn_df.loc[aux1, 'housing'] = 1

aux = knn_df['loan'] == 'no'
aux1 = knn_df['loan'] == 'yes'

# Convert
knn_df.loc[aux, 'loan'] = 0
knn_df.loc[aux1, 'loan'] = 1

# %%
# %%time
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2,weights='uniform',metric='nan_euclidean')
x= knn_df[["default","housing","loan"]]
x=imputer.fit_transform(x)
knn_df.loc[:,["default","housing","loan"]]= x
# Out:
# Wall time: 24.4 s

# %%
#Binarization of the imputation done by KNN

knn_df["loan"] = knn_df.loan.astype(bool).astype(float)
knn_df["housing"] = knn_df.housing.astype(bool).astype(float)
knn_df["default"] = knn_df.default.astype(bool).astype(float)

# %%
knn_df.isnull().mean()*100
# Out:
# age               0.000000
# job               0.801204
# marital           0.194231
# education         4.202680
# default           0.000000
# housing           0.000000
# loan              0.000000
# contact           0.000000
# month             0.000000
# day_of_week       0.000000
# campaign          0.000000
# pdays             0.000000
# previous          0.000000
# poutcome          0.000000
# emp.var.rate      0.000000
# cons.price.idx    0.000000
# cons.conf.idx     0.000000
# euribor3m         0.000000
# nr.employed       0.000000
# y                 0.000000
# pdays_range       0.000000
# dtype: float64

# %%
knn_df.dropna(subset=["job", "marital", "education"],axis=0,inplace=True)

# %%
knn_df.shape
# Out:
# (39191, 21)

# %% [markdown]
# ###  2) Drop all null values (prefered option)

# %%
df_dropna=df.copy()

# %%
df_dropna= df_dropna.replace(to_replace="unknown" ,value=np.NaN,regex=True)

# %%
df_dropna.dropna(axis=0,inplace=True)

# %%
df_dropna.isnull().mean()
# Out:
# age               0.0
# job               0.0
# marital           0.0
# education         0.0
# default           0.0
# housing           0.0
# loan              0.0
# contact           0.0
# month             0.0
# day_of_week       0.0
# campaign          0.0
# pdays             0.0
# previous          0.0
# poutcome          0.0
# emp.var.rate      0.0
# cons.price.idx    0.0
# cons.conf.idx     0.0
# euribor3m         0.0
# nr.employed       0.0
# y                 0.0
# pdays_range       0.0
# dtype: float64

# %%
sorted_df = df.sort_values("default")

# %%
import missingno as msno

# %%
msno.heatmap(sorted_df, figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
msno.dendrogram(sorted_df, figsize=(15,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Modeling

# %%
df.dtypes
# Out:
# age                float64
# job                 object
# marital             object
# education           object
# default             object
# housing             object
# loan                object
# contact             object
# month               object
# day_of_week         object
# campaign           float64
# pdays                int64
# previous             int64
# poutcome            object
# emp.var.rate       float64
# cons.price.idx     float64
# cons.conf.idx      float64
# euribor3m          float64
# nr.employed        float64
# y                    int32
# pdays_range       category
# dtype: object

# %%
numerical_cols = df.select_dtypes(include=[np.number]).columns.to_list()
numerical_cols.remove("y")
numerical_cols
# Out:
# ['age',
#  'campaign',
#  'pdays',
#  'previous',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %%
categorical_cols = df.select_dtypes(include="object").columns.to_list()
categorical_cols
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome']

# %% [markdown]
# ## KNNImputer

# %%
from pycaret.classification import *

# %%
clfs = setup(data = knn_df, target = 'y',
             session_id=234, normalize=True, 
             numeric_features=numerical_cols, categorical_features=categorical_cols, 
             transformation = True, 
             remove_multicollinearity = True, multicollinearity_threshold = 0.95, 
             fix_imbalance=True,
             data_split_stratify=True,
             fold_shuffle=True)
# Out:
# <style type="text/css">
# #T_f134e_row29_col1, #T_f134e_row31_col1, #T_f134e_row42_col1, #T_f134e_row56_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f134e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f134e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f134e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f134e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f134e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f134e_row0_col1" class="data row0 col1" >234</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f134e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f134e_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f134e_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_f134e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f134e_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_f134e_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f134e_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_f134e_row4_col1" class="data row4 col1" >(39191, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f134e_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_f134e_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f134e_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_f134e_row6_col1" class="data row6 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f134e_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_f134e_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f134e_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_f134e_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f134e_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_f134e_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f134e_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_f134e_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f134e_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_f134e_row11_col1" class="data row11 col1" >(27433, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f134e_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_f134e_row12_col1" class="data row12 col1" >(11758, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f134e_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_f134e_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f134e_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_f134e_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f134e_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_f134e_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f134e_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_f134e_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f134e_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_f134e_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f134e_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_f134e_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f134e_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_f134e_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f134e_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_f134e_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f134e_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_f134e_row21_col1" class="data row21 col1" >86fe</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f134e_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_f134e_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f134e_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_f134e_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f134e_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_f134e_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_f134e_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_f134e_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_f134e_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_f134e_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_f134e_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_f134e_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_f134e_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_f134e_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_f134e_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_f134e_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f134e_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_f134e_row30_col0" class="data row30 col0" >Nor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22764\3330620895.py in <module>
# ----> 1 clfs = setup(data = knn_df, target = 'y',
#       2              session_id=234, normalize=True,
#       3              numeric_features=numerical_cols, categorical_features=categorical_cols,
#       4              transformation = True,
#       5              remove_multicollinearity = True, multicollinearity_threshold = 0.95,
#
# ~\anaconda3\lib\site-packages\pycaret\classification.py in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     578         log_plots = ["auc", "confusion_matrix", "feature"]
#     579
# --> 580     return pycaret.internal.tabular.setup(
#     581         ml_usecase="classification",
#     582         available_plots=available_plots,
#
# ~\anaconda3\lib\site-packages\pycaret\internal\tabular.py in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1748     logger.info(f"display_container: {len(display_container)}")
#    1749
# -> 1750     logger.info(str(prep_pipe))
#    1751     logger.info("setup() succesfully completed......................................")
#    1752
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in __repr__(self, N_CHAR_MAX)
#     277         )
#     278
# --> 279         repr_ = pp.pformat(self)
#     280
#     281         # Use bruteforce ellipsis when there are a lot of non-blank characters
#
# ~\anaconda3\lib\pprint.py in pformat(self, object)
#     151     def pformat(self, object):
#     152         sio = _StringIO()
# --> 153         self._format(object, sio, 0, 0, {}, 0)
#     154         return sio.getvalue()
#     155
#
# ~\anaconda3\lib\pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     168             self._readable = False
#     169             return
# --> 170         rep = self._repr(object, context, level)
#     171         max_width = self._width - indent - allowance
#     172         if len(rep) > max_width:
#
# ~\anaconda3\lib\pprint.py in _repr(self, object, context, level)
#     429
#     430     def _repr(self, object, context, level):
# --> 431         repr, readable, recursive = self.format(object, context.copy(),
#     432                                                 self._depth, level)
#     433         if not readable:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in format(self, object, context, maxlevels, level)
#     187
#     188     def format(self, object, context, maxlevels, level):
# --> 189         return _safe_repr(
#     190             object, context, maxlevels, level, changed_only=self._changed_only
#     191         )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     450                 k, context, maxlevels, level, changed_only=changed_only
#     451             )
# --> 452             vrepr, vreadable, vrecur = saferepr(
#     453                 v, context, maxlevels, level, changed_only=changed_only
#     454             )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     417         level += 1
#     418         for o in object:
# --> 419             orepr, oreadable, orecur = _safe_repr(
#     420                 o, context, maxlevels, level, changed_only=changed_only
#     421             )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     417         level += 1
#     418         for o in object:
# --> 419             orepr, oreadable, orecur = _safe_repr(
#     420                 o, context, maxlevels, level, changed_only=changed_only
#     421             )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     440             params = _changed_params(object)
#     441         else:
# --> 442             params = object.get_params(deep=False)
#     443         components = []
#     444         append = components.append
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in get_params(self, deep)
#     208         out = dict()
#     209         for key in self._get_param_names():
# --> 210             value = getattr(self, key)
#     211             if deep and hasattr(value, "get_params"):
#     212                 deep_items = value.get_params().items()
#
# AttributeError: 'Simple_Imputer' object has no attribute 'fill_value_categorical'

# %%
models = compare_models(sort="AUC", n_select=5)
# Out:
# <style type="text/css">
# #T_f8bfa th {
#   text-align: left;
# }
# #T_f8bfa_row0_col0, #T_f8bfa_row0_col1, #T_f8bfa_row0_col3, #T_f8bfa_row0_col4, #T_f8bfa_row0_col5, #T_f8bfa_row0_col6, #T_f8bfa_row0_col7, #T_f8bfa_row1_col0, #T_f8bfa_row1_col2, #T_f8bfa_row1_col3, #T_f8bfa_row1_col5, #T_f8bfa_row1_col6, #T_f8bfa_row1_col7, #T_f8bfa_row2_col0, #T_f8bfa_row2_col1, #T_f8bfa_row2_col2, #T_f8bfa_row2_col3, #T_f8bfa_row2_col4, #T_f8bfa_row2_col5, #T_f8bfa_row2_col6, #T_f8bfa_row2_col7, #T_f8bfa_row3_col0, #T_f8bfa_row3_col1, #T_f8bfa_row3_col2, #T_f8bfa_row3_col3, #T_f8bfa_row3_col4, #T_f8bfa_row3_col5, #T_f8bfa_row3_col6, #T_f8bfa_row3_col7, #T_f8bfa_row4_col0, #T_f8bfa_row4_col1, #T_f8bfa_row4_col2, #T_f8bfa_row4_col3, #T_f8bfa_row4_col4, #T_f8bfa_row5_col0, #T_f8bfa_row5_col1, #T_f8bfa_row5_col2, #T_f8bfa_row5_col3, #T_f8bfa_row5_col4, #T_f8bfa_row5_col5, #T_f8bfa_row5_col6, #T_f8bfa_row5_col7, #T_f8bfa_row6_col0, #T_f8bfa_row6_col1, #T_f8bfa_row6_col2, #T_f8bfa_row6_col3, #T_f8bfa_row6_col4, #T_f8bfa_row6_col5, #T_f8bfa_row6_col6, #T_f8bfa_row6_col7, #T_f8bfa_row7_col0, #T_f8bfa_row7_col1, #T_f8bfa_row7_col2, #T_f8bfa_row7_col3, #T_f8bfa_row7_col4, #T_f8bfa_row7_col5, #T_f8bfa_row7_col6, #T_f8bfa_row7_col7, #T_f8bfa_row8_col0, #T_f8bfa_row8_col1, #T_f8bfa_row8_col2, #T_f8bfa_row8_col3, #T_f8bfa_row8_col4, #T_f8bfa_row8_col5, #T_f8bfa_row8_col6, #T_f8bfa_row8_col7, #T_f8bfa_row9_col0, #T_f8bfa_row9_col1, #T_f8bfa_row9_col2, #T_f8bfa_row9_col3, #T_f8bfa_row9_col4, #T_f8bfa_row9_col5, #T_f8bfa_row9_col6, #T_f8bfa_row9_col7, #T_f8bfa_row10_col0, #T_f8bfa_row10_col1, #T_f8bfa_row10_col2, #T_f8bfa_row10_col3, #T_f8bfa_row10_col4, #T_f8bfa_row10_col5, #T_f8bfa_row10_col6, #T_f8bfa_row10_col7, #T_f8bfa_row11_col0, #T_f8bfa_row11_col1, #T_f8bfa_row11_col2, #T_f8bfa_row11_col3, #T_f8bfa_row11_col4, #T_f8bfa_row11_col5, #T_f8bfa_row11_col6, #T_f8bfa_row11_col7, #T_f8bfa_row12_col0, #T_f8bfa_row12_col1, #T_f8bfa_row12_col2, #T_f8bfa_row12_col4, #T_f8bfa_row12_col5, #T_f8bfa_row12_col6, #T_f8bfa_row12_col7, #T_f8bfa_row13_col0, #T_f8bfa_row13_col1, #T_f8bfa_row13_col2, #T_f8bfa_row13_col3, #T_f8bfa_row13_col4, #T_f8bfa_row13_col5, #T_f8bfa_row13_col6, #T_f8bfa_row13_col7, #T_f8bfa_row14_col0, #T_f8bfa_row14_col1, #T_f8bfa_row14_col2, #T_f8bfa_row14_col3, #T_f8bfa_row14_col4, #T_f8bfa_row14_col5, #T_f8bfa_row14_col6, #T_f8bfa_row14_col7 {
#   text-align: left;
# }
# #T_f8bfa_row0_col2, #T_f8bfa_row1_col1, #T_f8bfa_row1_col4, #T_f8bfa_row4_col5, #T_f8bfa_row4_col6, #T_f8bfa_row4_col7, #T_f8bfa_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f8bfa_row0_col8, #T_f8bfa_row1_col8, #T_f8bfa_row2_col8, #T_f8bfa_row3_col8, #T_f8bfa_row4_col8, #T_f8bfa_row5_col8, #T_f8bfa_row6_col8, #T_f8bfa_row7_col8, #T_f8bfa_row8_col8, #T_f8bfa_row10_col8, #T_f8bfa_row11_col8, #T_f8bfa_row12_col8, #T_f8bfa_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f8bfa_row9_col8, #T_f8bfa_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f8bfa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8bfa_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f8bfa_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f8bfa_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f8bfa_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f8bfa_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f8bfa_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f8bfa_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f8bfa_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f8bfa_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8bfa_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_f8bfa_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f8bfa_row0_col1" class="data row0 col1" >0.8980</td>
#       <td id="T_f8bfa_row0_col2" class="data row0 col2" >0.7922</td>
#       <td id="T_f8bfa_row0_col3" class="data row0 col3" >0.3224</td>
#       <td id="T_f8bfa_row0_col4" class="data row0 col4" >0.5737</td>
#       <td id="T_f8bfa_row0_col5" class="data row0 col5" >0.4127</td>
#       <td id="T_f8bfa_row0_col6" class="data row0 col6" >0.3617</td>
#       <td id="T_f8bfa_row0_col7" class="data row0 col7" >0.3798</td>
#       <td id="T_f8bfa_row0_col8" class="data row0 col8" >0.4480</td>
#     </tr>
#     <tr>
#       <th id="T_f8bfa_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_f8bfa_row1_col0" class="data row1 col0" >CatBoost Classifier</td>
#       <td id="T_f8bfa_row1_col1" class="data row1 col1" >0.8988</td>
#       <td id="T_f8bfa_row1_col2" class="data row1 col2" >0.7855</td>
#       <td id="T_f8bfa_row1_col3" class="data row1 col3" >0.3041</td>
#       <td id="T_f8bfa_row1_col4" class="data row1 col4" >0.5873</td>
#       <td id="T_f8bfa_row1_col5" class="data row1 col5" >0.4004</td>
#       <td id="T_f8bfa_row1_col6" class="data row1 col6" >0.3512</td>
#       <td id="T_f8bfa_row1_col7" class="data row1 col7" >0.3741</td>
#       <td id="T_f8bfa_row1_col8" class="data row1 col8" >15.8960</td>
#     </tr>
#     <tr>
#       <th id="T_f8bfa_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_f8bfa_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_f8bfa_row2_col1" class="data row2 col1" >0.8189</td>
#       <td id="T_f8bfa_row2_col2" class="data row2 col2" >0.7822</td>
#       <td id="T_f8bfa_row2_col3" class="data row2 col3" >0.6153</td>
#       <td id="T_f8bfa_row2_col4" class="data row2 col4" >0.3312</td>
#       <td id="T_f8bfa_row2_col5" class="data row2 col5" >0.4305</td>
#       <td id="T_f8bfa_row2_col6" class="data row2 col6" >0.3342</td>
#       <td id="T_f8bfa_row2_col7" class="data row2 col7" >0.3570</td>
#       <td id="T_f8bfa_row2_col8" class="data row2 col8" >0.5910</td>
#     </tr>
#     <tr>
#       <th id="T_f8bfa_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_f8bfa_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_f8bfa_row3_col1" class="data row3 col1" >0.8188</td>
#       <td id="T_f8bfa_row3_col2" class="data row3 col2" >0.7820</td>
#       <td id="T_f8bfa_row3_col3" class="data row3 col3" >0.6166</td>
#       <td id="T_f8bfa_row3_col4" class="data row3 col4" >0.3312</td>
#       <td id="T_f8bfa_row3_col5" class="data row3 col5" >0.4308</td>
#       <td id="T_f8bfa_row3_col6" class="data row3 col6" >0.3345</td>
#       <td id="T_f8bfa_row3_col7" class="data row3 col7" >0.3575</td>
#       <td id="T_f8bfa_row3_col8" class="data row3 col8" >0.1720</td>
#     </tr>
#     <tr>
#       <th id="T_f8bfa_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_f8bfa_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_f8bfa_row4_col1" class="data row4 col1" >0.8835</td>
#       <td id="T_f8bfa_row4_col2" class="data row4 col2" >0.7781</td>
#       <td id="T_f8bfa_row4_col3" class="data row4 col3" >0.4499</td>
#       <td id="T_f8bfa_row4_col4" class="data row4 col4" >0.4751</td>
#       <td id="T_f8bfa_row4_col5" class="data row4 col5" >0.4619</td>
#       <td id="T_f8bfa_row4_col6" class="data row4 col6" >0.3967</td>
#       <td id="T_f8bfa_row4_col7" class="data row4 col7" >0.3970</td>
#       <td id="T_f8bfa_row4_col8" class="data row4 col8" >2.1970</td>
#     </tr>
#     <tr>
#       <th id="T_f8bfa_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_f8bfa_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_f8bfa_row5_col1" class="data row5 col1" >0.8978</td>
#       <td id="T_f8bfa_row5_col2" class="data row5 col2" >0.7779</td>
#       <td id="T_f8bfa_row5_col3" class="data row5 col3" >0.3038</td>
#       <td id="T_f8bfa_row5_col4" class="data row5 col4" >0.5760</td>

# %% [markdown]
# ### Dropping null values

# %%
clfs = setup(data = df_dropna, target = 'y',
             session_id=234, normalize=True, 
             numeric_features=numerical_cols, categorical_features=categorical_cols, 
             transformation = True, 
             remove_multicollinearity = True, multicollinearity_threshold = 0.95, 
             fix_imbalance=True,
             data_split_stratify=True,
             fold_shuffle=True)
# Out:
# <style type="text/css">
# #T_72af7_row29_col1, #T_72af7_row31_col1, #T_72af7_row42_col1, #T_72af7_row56_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_72af7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72af7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_72af7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72af7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72af7_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_72af7_row0_col1" class="data row0 col1" >234</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72af7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_72af7_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72af7_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_72af7_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72af7_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_72af7_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_72af7_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_72af7_row4_col1" class="data row4 col1" >(30488, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_72af7_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_72af7_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_72af7_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_72af7_row6_col1" class="data row6 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_72af7_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_72af7_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_72af7_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_72af7_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_72af7_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_72af7_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_72af7_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_72af7_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_72af7_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_72af7_row11_col1" class="data row11 col1" >(21341, 54)</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_72af7_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_72af7_row12_col1" class="data row12 col1" >(9147, 54)</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_72af7_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_72af7_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_72af7_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_72af7_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_72af7_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_72af7_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_72af7_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_72af7_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_72af7_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_72af7_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_72af7_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_72af7_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_72af7_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_72af7_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_72af7_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_72af7_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_72af7_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_72af7_row21_col1" class="data row21 col1" >a695</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_72af7_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_72af7_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_72af7_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_72af7_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_72af7_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_72af7_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_72af7_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_72af7_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_72af7_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_72af7_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_72af7_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_72af7_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_72af7_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_72af7_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_72af7_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_72af7_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_72af7_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_72af7_row30_col0" class="data row30 col0" >Norm
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22764\4154321042.py in <module>
# ----> 1 clfs = setup(data = df_dropna, target = 'y',
#       2              session_id=234, normalize=True,
#       3              numeric_features=numerical_cols, categorical_features=categorical_cols,
#       4              transformation = True,
#       5              remove_multicollinearity = True, multicollinearity_threshold = 0.95,
#
# ~\anaconda3\lib\site-packages\pycaret\classification.py in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     578         log_plots = ["auc", "confusion_matrix", "feature"]
#     579
# --> 580     return pycaret.internal.tabular.setup(
#     581         ml_usecase="classification",
#     582         available_plots=available_plots,
#
# ~\anaconda3\lib\site-packages\pycaret\internal\tabular.py in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1748     logger.info(f"display_container: {len(display_container)}")
#    1749
# -> 1750     logger.info(str(prep_pipe))
#    1751     logger.info("setup() succesfully completed......................................")
#    1752
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in __repr__(self, N_CHAR_MAX)
#     277         )
#     278
# --> 279         repr_ = pp.pformat(self)
#     280
#     281         # Use bruteforce ellipsis when there are a lot of non-blank characters
#
# ~\anaconda3\lib\pprint.py in pformat(self, object)
#     151     def pformat(self, object):
#     152         sio = _StringIO()
# --> 153         self._format(object, sio, 0, 0, {}, 0)
#     154         return sio.getvalue()
#     155
#
# ~\anaconda3\lib\pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     168             self._readable = False
#     169             return
# --> 170         rep = self._repr(object, context, level)
#     171         max_width = self._width - indent - allowance
#     172         if len(rep) > max_width:
#
# ~\anaconda3\lib\pprint.py in _repr(self, object, context, level)
#     429
#     430     def _repr(self, object, context, level):
# --> 431         repr, readable, recursive = self.format(object, context.copy(),
#     432                                                 self._depth, level)
#     433         if not readable:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in format(self, object, context, maxlevels, level)
#     187
#     188     def format(self, object, context, maxlevels, level):
# --> 189         return _safe_repr(
#     190             object, context, maxlevels, level, changed_only=self._changed_only
#     191         )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     450                 k, context, maxlevels, level, changed_only=changed_only
#     451             )
# --> 452             vrepr, vreadable, vrecur = saferepr(
#     453                 v, context, maxlevels, level, changed_only=changed_only
#     454             )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     417         level += 1
#     418         for o in object:
# --> 419             orepr, oreadable, orecur = _safe_repr(
#     420                 o, context, maxlevels, level, changed_only=changed_only
#     421             )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     417         level += 1
#     418         for o in object:
# --> 419             orepr, oreadable, orecur = _safe_repr(
#     420                 o, context, maxlevels, level, changed_only=changed_only
#     421             )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     440             params = _changed_params(object)
#     441         else:
# --> 442             params = object.get_params(deep=False)
#     443         components = []
#     444         append = components.append
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in get_params(self, deep)
#     208         out = dict()
#     209         for key in self._get_param_names():
# --> 210             value = getattr(self, key)
#     211             if deep and hasattr(value, "get_params"):
#     212                 deep_items = value.get_params().items()
#
# AttributeError: 'Simple_Imputer' object has no attribute 'fill_value_categorical'

# %%
models = compare_models(sort="AUC", n_select=5)
# Out:
# <style type="text/css">
# #T_74520 th {
#   text-align: left;
# }
# #T_74520_row0_col0, #T_74520_row0_col3, #T_74520_row0_col5, #T_74520_row0_col6, #T_74520_row0_col7, #T_74520_row1_col0, #T_74520_row1_col1, #T_74520_row1_col2, #T_74520_row1_col3, #T_74520_row1_col4, #T_74520_row1_col5, #T_74520_row1_col6, #T_74520_row1_col7, #T_74520_row2_col0, #T_74520_row2_col1, #T_74520_row2_col2, #T_74520_row2_col3, #T_74520_row2_col4, #T_74520_row2_col5, #T_74520_row2_col6, #T_74520_row2_col7, #T_74520_row3_col0, #T_74520_row3_col1, #T_74520_row3_col2, #T_74520_row3_col3, #T_74520_row3_col4, #T_74520_row4_col0, #T_74520_row4_col1, #T_74520_row4_col2, #T_74520_row4_col3, #T_74520_row4_col4, #T_74520_row4_col5, #T_74520_row4_col6, #T_74520_row4_col7, #T_74520_row5_col0, #T_74520_row5_col1, #T_74520_row5_col2, #T_74520_row5_col3, #T_74520_row5_col4, #T_74520_row5_col5, #T_74520_row5_col6, #T_74520_row5_col7, #T_74520_row6_col0, #T_74520_row6_col1, #T_74520_row6_col2, #T_74520_row6_col3, #T_74520_row6_col4, #T_74520_row6_col5, #T_74520_row6_col6, #T_74520_row6_col7, #T_74520_row7_col0, #T_74520_row7_col1, #T_74520_row7_col2, #T_74520_row7_col3, #T_74520_row7_col4, #T_74520_row7_col5, #T_74520_row7_col6, #T_74520_row7_col7, #T_74520_row8_col0, #T_74520_row8_col1, #T_74520_row8_col2, #T_74520_row8_col3, #T_74520_row8_col4, #T_74520_row8_col5, #T_74520_row8_col6, #T_74520_row8_col7, #T_74520_row9_col0, #T_74520_row9_col1, #T_74520_row9_col2, #T_74520_row9_col3, #T_74520_row9_col4, #T_74520_row9_col5, #T_74520_row9_col6, #T_74520_row9_col7, #T_74520_row10_col0, #T_74520_row10_col1, #T_74520_row10_col2, #T_74520_row10_col3, #T_74520_row10_col4, #T_74520_row10_col5, #T_74520_row10_col6, #T_74520_row10_col7, #T_74520_row11_col0, #T_74520_row11_col1, #T_74520_row11_col2, #T_74520_row11_col3, #T_74520_row11_col4, #T_74520_row11_col5, #T_74520_row11_col6, #T_74520_row11_col7, #T_74520_row12_col0, #T_74520_row12_col1, #T_74520_row12_col2, #T_74520_row12_col4, #T_74520_row12_col5, #T_74520_row12_col6, #T_74520_row12_col7, #T_74520_row13_col0, #T_74520_row13_col1, #T_74520_row13_col2, #T_74520_row13_col3, #T_74520_row13_col4, #T_74520_row13_col5, #T_74520_row13_col6, #T_74520_row13_col7, #T_74520_row14_col0, #T_74520_row14_col1, #T_74520_row14_col2, #T_74520_row14_col3, #T_74520_row14_col4, #T_74520_row14_col5, #T_74520_row14_col6, #T_74520_row14_col7 {
#   text-align: left;
# }
# #T_74520_row0_col1, #T_74520_row0_col2, #T_74520_row0_col4, #T_74520_row3_col5, #T_74520_row3_col6, #T_74520_row3_col7, #T_74520_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_74520_row0_col8, #T_74520_row1_col8, #T_74520_row2_col8, #T_74520_row3_col8, #T_74520_row4_col8, #T_74520_row5_col8, #T_74520_row6_col8, #T_74520_row7_col8, #T_74520_row9_col8, #T_74520_row10_col8, #T_74520_row11_col8, #T_74520_row12_col8, #T_74520_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_74520_row8_col8, #T_74520_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_74520">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74520_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_74520_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_74520_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_74520_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_74520_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_74520_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_74520_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_74520_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_74520_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74520_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_74520_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_74520_row0_col1" class="data row0 col1" >0.8840</td>
#       <td id="T_74520_row0_col2" class="data row0 col2" >0.7926</td>
#       <td id="T_74520_row0_col3" class="data row0 col3" >0.3206</td>
#       <td id="T_74520_row0_col4" class="data row0 col4" >0.5753</td>
#       <td id="T_74520_row0_col5" class="data row0 col5" >0.4113</td>
#       <td id="T_74520_row0_col6" class="data row0 col6" >0.3527</td>
#       <td id="T_74520_row0_col7" class="data row0 col7" >0.3715</td>
#       <td id="T_74520_row0_col8" class="data row0 col8" >0.3850</td>
#     </tr>
#     <tr>
#       <th id="T_74520_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_74520_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_74520_row1_col1" class="data row1 col1" >0.8044</td>
#       <td id="T_74520_row1_col2" class="data row1 col2" >0.7923</td>
#       <td id="T_74520_row1_col3" class="data row1 col3" >0.6527</td>
#       <td id="T_74520_row1_col4" class="data row1 col4" >0.3529</td>
#       <td id="T_74520_row1_col5" class="data row1 col5" >0.4580</td>
#       <td id="T_74520_row1_col6" class="data row1 col6" >0.3515</td>
#       <td id="T_74520_row1_col7" class="data row1 col7" >0.3763</td>
#       <td id="T_74520_row1_col8" class="data row1 col8" >0.4680</td>
#     </tr>
#     <tr>
#       <th id="T_74520_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_74520_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_74520_row2_col1" class="data row2 col1" >0.8001</td>
#       <td id="T_74520_row2_col2" class="data row2 col2" >0.7914</td>
#       <td id="T_74520_row2_col3" class="data row2 col3" >0.6546</td>
#       <td id="T_74520_row2_col4" class="data row2 col4" >0.3469</td>
#       <td id="T_74520_row2_col5" class="data row2 col5" >0.4533</td>
#       <td id="T_74520_row2_col6" class="data row2 col6" >0.3449</td>
#       <td id="T_74520_row2_col7" class="data row2 col7" >0.3710</td>
#       <td id="T_74520_row2_col8" class="data row2 col8" >0.1200</td>
#     </tr>
#     <tr>
#       <th id="T_74520_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_74520_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_74520_row3_col1" class="data row3 col1" >0.8722</td>
#       <td id="T_74520_row3_col2" class="data row3 col2" >0.7888</td>
#       <td id="T_74520_row3_col3" class="data row3 col3" >0.4683</td>
#       <td id="T_74520_row3_col4" class="data row3 col4" >0.4957</td>
#       <td id="T_74520_row3_col5" class="data row3 col5" >0.4812</td>
#       <td id="T_74520_row3_col6" class="data row3 col6" >0.4085</td>
#       <td id="T_74520_row3_col7" class="data row3 col7" >0.4089</td>
#       <td id="T_74520_row3_col8" class="data row3 col8" >1.5180</td>
#     </tr>
#     <tr>
#       <th id="T_74520_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_74520_row4_col0" class="data row4 col0" >CatBoost Classifier</td>
#       <td id="T_74520_row4_col1" class="data row4 col1" >0.8828</td>
#       <td id="T_74520_row4_col2" class="data row4 col2" >0.7877</td>
#       <td id="T_74520_row4_col3" class="data row4 col3" >0.3047</td>
#       <td id="T_74520_row4_col4" class="data row4 col4" >0.5690</td>
#       <td id="T_74520_row4_col5" class="data row4 col5" >0.3965</td>
#       <td id="T_74520_row4_col6" class="data row4 col6" >0.3382</td>
#       <td id="T_74520_row4_col7" class="data row4 col7" >0.3587</td>
#       <td id="T_74520_row4_col8" class="data row4 col8" >14.1200</td>
#     </tr>
#     <tr>
#       <th id="T_74520_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_74520_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_74520_row5_col1" class="data row5 col1" >0.8819</td>
#       <td id="T_74520_row5_col2" class="data row5 col2" >0.7754</td>
#       <td id="T_74520_row5_col3" class="data row5 col3" >0.3032</td>
#       <td id="T_74520_row5_col4" class="data row5 col4" >0.5608</td>

# %% [markdown]
# ### "Unknown" as a category

# %%
clfs = setup(data = df, target = 'y',
             session_id=234, normalize=True, 
             numeric_features=numerical_cols, categorical_features=categorical_cols, 
             transformation = True, 
             remove_multicollinearity = True, multicollinearity_threshold = 0.95, 
             fix_imbalance=True,
             data_split_stratify=True,
             fold_shuffle=True)
# Out:
# <style type="text/css">
# #T_62b79_row5_col1, #T_62b79_row29_col1, #T_62b79_row31_col1, #T_62b79_row42_col1, #T_62b79_row56_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_62b79">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62b79_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_62b79_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62b79_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_62b79_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_62b79_row0_col1" class="data row0 col1" >234</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_62b79_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_62b79_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_62b79_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_62b79_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_62b79_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_62b79_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_62b79_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_62b79_row4_col1" class="data row4 col1" >(41188, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_62b79_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_62b79_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_62b79_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_62b79_row6_col1" class="data row6 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_62b79_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_62b79_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_62b79_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_62b79_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_62b79_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_62b79_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_62b79_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_62b79_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_62b79_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_62b79_row11_col1" class="data row11 col1" >(28831, 61)</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_62b79_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_62b79_row12_col1" class="data row12 col1" >(12357, 61)</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_62b79_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_62b79_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_62b79_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_62b79_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_62b79_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_62b79_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_62b79_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_62b79_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_62b79_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_62b79_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_62b79_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_62b79_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_62b79_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_62b79_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_62b79_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_62b79_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_62b79_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_62b79_row21_col1" class="data row21 col1" >bc6d</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_62b79_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_62b79_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_62b79_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_62b79_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_62b79_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_62b79_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_62b79_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_62b79_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_62b79_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_62b79_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_62b79_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_62b79_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_62b79_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_62b79_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_62b79_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_62b79_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_62b79_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_62b79_row30_col0" class="da
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22764\888959342.py in <module>
# ----> 1 clfs = setup(data = df, target = 'y',
#       2              session_id=234, normalize=True,
#       3              numeric_features=numerical_cols, categorical_features=categorical_cols,
#       4              transformation = True,
#       5              remove_multicollinearity = True, multicollinearity_threshold = 0.95,
#
# ~\anaconda3\lib\site-packages\pycaret\classification.py in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     578         log_plots = ["auc", "confusion_matrix", "feature"]
#     579
# --> 580     return pycaret.internal.tabular.setup(
#     581         ml_usecase="classification",
#     582         available_plots=available_plots,
#
# ~\anaconda3\lib\site-packages\pycaret\internal\tabular.py in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1748     logger.info(f"display_container: {len(display_container)}")
#    1749
# -> 1750     logger.info(str(prep_pipe))
#    1751     logger.info("setup() succesfully completed......................................")
#    1752
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in __repr__(self, N_CHAR_MAX)
#     277         )
#     278
# --> 279         repr_ = pp.pformat(self)
#     280
#     281         # Use bruteforce ellipsis when there are a lot of non-blank characters
#
# ~\anaconda3\lib\pprint.py in pformat(self, object)
#     151     def pformat(self, object):
#     152         sio = _StringIO()
# --> 153         self._format(object, sio, 0, 0, {}, 0)
#     154         return sio.getvalue()
#     155
#
# ~\anaconda3\lib\pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     168             self._readable = False
#     169             return
# --> 170         rep = self._repr(object, context, level)
#     171         max_width = self._width - indent - allowance
#     172         if len(rep) > max_width:
#
# ~\anaconda3\lib\pprint.py in _repr(self, object, context, level)
#     429
#     430     def _repr(self, object, context, level):
# --> 431         repr, readable, recursive = self.format(object, context.copy(),
#     432                                                 self._depth, level)
#     433         if not readable:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in format(self, object, context, maxlevels, level)
#     187
#     188     def format(self, object, context, maxlevels, level):
# --> 189         return _safe_repr(
#     190             object, context, maxlevels, level, changed_only=self._changed_only
#     191         )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     450                 k, context, maxlevels, level, changed_only=changed_only
#     451             )
# --> 452             vrepr, vreadable, vrecur = saferepr(
#     453                 v, context, maxlevels, level, changed_only=changed_only
#     454             )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     417         level += 1
#     418         for o in object:
# --> 419             orepr, oreadable, orecur = _safe_repr(
#     420                 o, context, maxlevels, level, changed_only=changed_only
#     421             )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     417         level += 1
#     418         for o in object:
# --> 419             orepr, oreadable, orecur = _safe_repr(
#     420                 o, context, maxlevels, level, changed_only=changed_only
#     421             )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     440             params = _changed_params(object)
#     441         else:
# --> 442             params = object.get_params(deep=False)
#     443         components = []
#     444         append = components.append
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in get_params(self, deep)
#     208         out = dict()
#     209         for key in self._get_param_names():
# --> 210             value = getattr(self, key)
#     211             if deep and hasattr(value, "get_params"):
#     212                 deep_items = value.get_params().items()
#
# AttributeError: 'Simple_Imputer' object has no attribute 'fill_value_categorical'

# %%
models = compare_models(sort="AUC", n_select=5)
# Out:
# <style type="text/css">
# #T_b4dbf th {
#   text-align: left;
# }
# #T_b4dbf_row0_col0, #T_b4dbf_row0_col1, #T_b4dbf_row0_col3, #T_b4dbf_row0_col4, #T_b4dbf_row0_col5, #T_b4dbf_row0_col6, #T_b4dbf_row0_col7, #T_b4dbf_row1_col0, #T_b4dbf_row1_col2, #T_b4dbf_row1_col3, #T_b4dbf_row1_col5, #T_b4dbf_row1_col6, #T_b4dbf_row1_col7, #T_b4dbf_row2_col0, #T_b4dbf_row2_col1, #T_b4dbf_row2_col2, #T_b4dbf_row2_col3, #T_b4dbf_row2_col4, #T_b4dbf_row2_col5, #T_b4dbf_row2_col6, #T_b4dbf_row2_col7, #T_b4dbf_row3_col0, #T_b4dbf_row3_col1, #T_b4dbf_row3_col2, #T_b4dbf_row3_col3, #T_b4dbf_row3_col4, #T_b4dbf_row3_col5, #T_b4dbf_row3_col6, #T_b4dbf_row3_col7, #T_b4dbf_row4_col0, #T_b4dbf_row4_col1, #T_b4dbf_row4_col2, #T_b4dbf_row4_col3, #T_b4dbf_row4_col4, #T_b4dbf_row5_col0, #T_b4dbf_row5_col1, #T_b4dbf_row5_col2, #T_b4dbf_row5_col3, #T_b4dbf_row5_col4, #T_b4dbf_row5_col5, #T_b4dbf_row5_col6, #T_b4dbf_row5_col7, #T_b4dbf_row6_col0, #T_b4dbf_row6_col1, #T_b4dbf_row6_col2, #T_b4dbf_row6_col3, #T_b4dbf_row6_col4, #T_b4dbf_row6_col5, #T_b4dbf_row6_col6, #T_b4dbf_row6_col7, #T_b4dbf_row7_col0, #T_b4dbf_row7_col1, #T_b4dbf_row7_col2, #T_b4dbf_row7_col3, #T_b4dbf_row7_col4, #T_b4dbf_row7_col5, #T_b4dbf_row7_col6, #T_b4dbf_row7_col7, #T_b4dbf_row8_col0, #T_b4dbf_row8_col1, #T_b4dbf_row8_col2, #T_b4dbf_row8_col3, #T_b4dbf_row8_col4, #T_b4dbf_row8_col5, #T_b4dbf_row8_col6, #T_b4dbf_row8_col7, #T_b4dbf_row9_col0, #T_b4dbf_row9_col1, #T_b4dbf_row9_col2, #T_b4dbf_row9_col3, #T_b4dbf_row9_col4, #T_b4dbf_row9_col5, #T_b4dbf_row9_col6, #T_b4dbf_row9_col7, #T_b4dbf_row10_col0, #T_b4dbf_row10_col1, #T_b4dbf_row10_col2, #T_b4dbf_row10_col3, #T_b4dbf_row10_col4, #T_b4dbf_row10_col5, #T_b4dbf_row10_col6, #T_b4dbf_row10_col7, #T_b4dbf_row11_col0, #T_b4dbf_row11_col1, #T_b4dbf_row11_col2, #T_b4dbf_row11_col3, #T_b4dbf_row11_col4, #T_b4dbf_row11_col5, #T_b4dbf_row11_col6, #T_b4dbf_row11_col7, #T_b4dbf_row12_col0, #T_b4dbf_row12_col1, #T_b4dbf_row12_col2, #T_b4dbf_row12_col4, #T_b4dbf_row12_col5, #T_b4dbf_row12_col6, #T_b4dbf_row12_col7, #T_b4dbf_row13_col0, #T_b4dbf_row13_col1, #T_b4dbf_row13_col2, #T_b4dbf_row13_col3, #T_b4dbf_row13_col4, #T_b4dbf_row13_col5, #T_b4dbf_row13_col6, #T_b4dbf_row13_col7, #T_b4dbf_row14_col0, #T_b4dbf_row14_col1, #T_b4dbf_row14_col2, #T_b4dbf_row14_col3, #T_b4dbf_row14_col4, #T_b4dbf_row14_col5, #T_b4dbf_row14_col6, #T_b4dbf_row14_col7 {
#   text-align: left;
# }
# #T_b4dbf_row0_col2, #T_b4dbf_row1_col1, #T_b4dbf_row1_col4, #T_b4dbf_row4_col5, #T_b4dbf_row4_col6, #T_b4dbf_row4_col7, #T_b4dbf_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_b4dbf_row0_col8, #T_b4dbf_row1_col8, #T_b4dbf_row2_col8, #T_b4dbf_row3_col8, #T_b4dbf_row4_col8, #T_b4dbf_row5_col8, #T_b4dbf_row6_col8, #T_b4dbf_row7_col8, #T_b4dbf_row8_col8, #T_b4dbf_row10_col8, #T_b4dbf_row11_col8, #T_b4dbf_row12_col8, #T_b4dbf_row13_col8, #T_b4dbf_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_b4dbf_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_b4dbf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4dbf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b4dbf_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b4dbf_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b4dbf_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b4dbf_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b4dbf_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b4dbf_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b4dbf_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_b4dbf_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4dbf_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_b4dbf_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_b4dbf_row0_col1" class="data row0 col1" >0.8970</td>
#       <td id="T_b4dbf_row0_col2" class="data row0 col2" >0.8007</td>
#       <td id="T_b4dbf_row0_col3" class="data row0 col3" >0.3267</td>
#       <td id="T_b4dbf_row0_col4" class="data row0 col4" >0.5767</td>
#       <td id="T_b4dbf_row0_col5" class="data row0 col5" >0.4167</td>
#       <td id="T_b4dbf_row0_col6" class="data row0 col6" >0.3649</td>
#       <td id="T_b4dbf_row0_col7" class="data row0 col7" >0.3829</td>
#       <td id="T_b4dbf_row0_col8" class="data row0 col8" >0.3610</td>
#     </tr>
#     <tr>
#       <th id="T_b4dbf_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_b4dbf_row1_col0" class="data row1 col0" >CatBoost Classifier</td>
#       <td id="T_b4dbf_row1_col1" class="data row1 col1" >0.8973</td>
#       <td id="T_b4dbf_row1_col2" class="data row1 col2" >0.7962</td>
#       <td id="T_b4dbf_row1_col3" class="data row1 col3" >0.3045</td>
#       <td id="T_b4dbf_row1_col4" class="data row1 col4" >0.5855</td>
#       <td id="T_b4dbf_row1_col5" class="data row1 col5" >0.4001</td>
#       <td id="T_b4dbf_row1_col6" class="data row1 col6" >0.3501</td>
#       <td id="T_b4dbf_row1_col7" class="data row1 col7" >0.3728</td>
#       <td id="T_b4dbf_row1_col8" class="data row1 col8" >17.0010</td>
#     </tr>
#     <tr>
#       <th id="T_b4dbf_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_b4dbf_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_b4dbf_row2_col1" class="data row2 col1" >0.8231</td>
#       <td id="T_b4dbf_row2_col2" class="data row2 col2" >0.7903</td>
#       <td id="T_b4dbf_row2_col3" class="data row2 col3" >0.6352</td>
#       <td id="T_b4dbf_row2_col4" class="data row2 col4" >0.3458</td>
#       <td id="T_b4dbf_row2_col5" class="data row2 col5" >0.4476</td>
#       <td id="T_b4dbf_row2_col6" class="data row2 col6" >0.3532</td>
#       <td id="T_b4dbf_row2_col7" class="data row2 col7" >0.3764</td>
#       <td id="T_b4dbf_row2_col8" class="data row2 col8" >0.6330</td>
#     </tr>
#     <tr>
#       <th id="T_b4dbf_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_b4dbf_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_b4dbf_row3_col1" class="data row3 col1" >0.8210</td>
#       <td id="T_b4dbf_row3_col2" class="data row3 col2" >0.7895</td>
#       <td id="T_b4dbf_row3_col3" class="data row3 col3" >0.6352</td>
#       <td id="T_b4dbf_row3_col4" class="data row3 col4" >0.3421</td>
#       <td id="T_b4dbf_row3_col5" class="data row3 col5" >0.4446</td>
#       <td id="T_b4dbf_row3_col6" class="data row3 col6" >0.3492</td>
#       <td id="T_b4dbf_row3_col7" class="data row3 col7" >0.3730</td>
#       <td id="T_b4dbf_row3_col8" class="data row3 col8" >0.1990</td>
#     </tr>
#     <tr>
#       <th id="T_b4dbf_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_b4dbf_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_b4dbf_row4_col1" class="data row4 col1" >0.8844</td>
#       <td id="T_b4dbf_row4_col2" class="data row4 col2" >0.7889</td>
#       <td id="T_b4dbf_row4_col3" class="data row4 col3" >0.4818</td>
#       <td id="T_b4dbf_row4_col4" class="data row4 col4" >0.4872</td>
#       <td id="T_b4dbf_row4_col5" class="data row4 col5" >0.4844</td>
#       <td id="T_b4dbf_row4_col6" class="data row4 col6" >0.4193</td>
#       <td id="T_b4dbf_row4_col7" class="data row4 col7" >0.4193</td>
#       <td id="T_b4dbf_row4_col8" class="data row4 col8" >2.3980</td>
#     </tr>
#     <tr>
#       <th id="T_b4dbf_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_b4dbf_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_b4dbf_row5_col1" class="data row5 col1" >0.8966</td>
#       <td id="T_b4dbf_row5_col2" class="data row5 col2" >0.7887</td>
#       <td id="T_b4dbf_row5_col3" class="data row5 col3" >0.3033</td>
#       <td id="T_b4dbf_row5_col4" class="data row5 col4" >0.5786</td>

# %% [markdown]
# Our chosen model is LGBMClassifier. We are also trying the second and the third: CatBoost Classifier and Logistic Regression.

# %% [markdown]
# ### Chosen Model: LGBMClassifier

# %%
lgbm = create_model("lightgbm")
# Out:
# <style type="text/css">
# #T_a6d4a_row10_col0, #T_a6d4a_row10_col1, #T_a6d4a_row10_col2, #T_a6d4a_row10_col3, #T_a6d4a_row10_col4, #T_a6d4a_row10_col5, #T_a6d4a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a6d4a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6d4a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a6d4a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a6d4a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a6d4a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a6d4a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a6d4a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a6d4a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6d4a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6d4a_row0_col0" class="data row0 col0" >0.9012</td>
#       <td id="T_a6d4a_row0_col1" class="data row0 col1" >0.8086</td>
#       <td id="T_a6d4a_row0_col2" class="data row0 col2" >0.3477</td>
#       <td id="T_a6d4a_row0_col3" class="data row0 col3" >0.6075</td>
#       <td id="T_a6d4a_row0_col4" class="data row0 col4" >0.4423</td>
#       <td id="T_a6d4a_row0_col5" class="data row0 col5" >0.3924</td>
#       <td id="T_a6d4a_row0_col6" class="data row0 col6" >0.4109</td>
#     </tr>
#     <tr>
#       <th id="T_a6d4a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6d4a_row1_col0" class="data row1 col0" >0.9008</td>
#       <td id="T_a6d4a_row1_col1" class="data row1 col1" >0.7956</td>
#       <td id="T_a6d4a_row1_col2" class="data row1 col2" >0.3056</td>
#       <td id="T_a6d4a_row1_col3" class="data row1 col3" >0.6188</td>
#       <td id="T_a6d4a_row1_col4" class="data row1 col4" >0.4091</td>
#       <td id="T_a6d4a_row1_col5" class="data row1 col5" >0.3617</td>
#       <td id="T_a6d4a_row1_col6" class="data row1 col6" >0.3886</td>
#     </tr>
#     <tr>
#       <th id="T_a6d4a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6d4a_row2_col0" class="data row2 col0" >0.8904</td>
#       <td id="T_a6d4a_row2_col1" class="data row2 col1" >0.7904</td>
#       <td id="T_a6d4a_row2_col2" class="data row2 col2" >0.3333</td>
#       <td id="T_a6d4a_row2_col3" class="data row2 col3" >0.5192</td>
#       <td id="T_a6d4a_row2_col4" class="data row2 col4" >0.4060</td>
#       <td id="T_a6d4a_row2_col5" class="data row2 col5" >0.3488</td>
#       <td id="T_a6d4a_row2_col6" class="data row2 col6" >0.3592</td>
#     </tr>
#     <tr>
#       <th id="T_a6d4a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6d4a_row3_col0" class="data row3 col0" >0.8935</td>
#       <td id="T_a6d4a_row3_col1" class="data row3 col1" >0.7845</td>
#       <td id="T_a6d4a_row3_col2" class="data row3 col2" >0.2954</td>
#       <td id="T_a6d4a_row3_col3" class="data row3 col3" >0.5517</td>
#       <td id="T_a6d4a_row3_col4" class="data row3 col4" >0.3848</td>
#       <td id="T_a6d4a_row3_col5" class="data row3 col5" >0.3323</td>
#       <td id="T_a6d4a_row3_col6" class="data row3 col6" >0.3518</td>
#     </tr>
#     <tr>
#       <th id="T_a6d4a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6d4a_row4_col0" class="data row4 col0" >0.8998</td>
#       <td id="T_a6d4a_row4_col1" class="data row4 col1" >0.8266</td>
#       <td id="T_a6d4a_row4_col2" class="data row4 col2" >0.3446</td>
#       <td id="T_a6d4a_row4_col3" class="data row4 col3" >0.5957</td>
#       <td id="T_a6d4a_row4_col4" class="data row4 col4" >0.4366</td>
#       <td id="T_a6d4a_row4_col5" class="data row4 col5" >0.3859</td>
#       <td id="T_a6d4a_row4_col6" class="data row4 col6" >0.4034</td>
#     </tr>
#     <tr>
#       <th id="T_a6d4a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6d4a_row5_col0" class="data row5 col0" >0.8939</td>
#       <td id="T_a6d4a_row5_col1" class="data row5 col1" >0.7989</td>
#       <td id="T_a6d4a_row5_col2" class="data row5 col2" >0.3231</td>
#       <td id="T_a6d4a_row5_col3" class="data row5 col3" >0.5497</td>
#       <td id="T_a6d4a_row5_col4" class="data row5 col4" >0.4070</td>
#       <td id="T_a6d4a_row5_col5" class="data row5 col5" >0.3530</td>
#       <td id="T_a6d4a_row5_col6" class="data row5 col6" >0.3681</td>
#     </tr>
#     <tr>
#       <th id="T_a6d4a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a6d4a_row6_col0" class="data row6 col0" >0.8998</td>
#       <td id="T_a6d4a_row6_col1" class="data row6 col1" >0.7996</td>
#       <td id="T_a6d4a_row6_col2" class="data row6 col2" >0.3446</td>
#       <td id="T_a6d4a_row6_col3" class="data row6 col3" >0.5957</td>
#       <td id="T_a6d4a_row6_col4" class="data row6 col4" >0.4366</td>
#       <td id="T_a6d4a_row6_col5" class="data row6 col5" >0.3859</td>
#       <td id="T_a6d4a_row6_col6" class="data row6 col6" >0.4034</td>
#     </tr>
#     <tr>
#       <th id="T_a6d4a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a6d4a_row7_col0" class="data row7 col0" >0.8994</td>
#       <td id="T_a6d4a_row7_col1" class="data row7 col1" >0.7983</td>
#       <td id="T_a6d4a_row7_col2" class="data row7 col2" >0.3262</td>
#       <td id="T_a6d4a_row7_col3" class="data row7 col3" >0.5989</td>
#       <td id="T_a6d4a_row7_col4" class="data row7 col4" >0.4223</td>
#       <td id="T_a6d4a_row7_col5" class="data row7 col5" >0.3724</td>
#       <td id="T_a6d4a_row7_col6" class="data row7 col6" >0.3931</td>
#     </tr>
#     <tr>
#       <th id="T_a6d4a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a6d4a_row8_col0" class="data row8 col0" >0.8949</td>
#       <td id="T_a6d4a_row8_col1" class="data row8 col1" >0.8183</td>
#       <td id="T_a6d4a_row8_col2" class="data row8 col2" >0.3292</td>
#       <td id="T_a6d4a_row8_col3" class="data row8 col3" >0.5573</td>
#       <td id="T_a6d4a_row8_col4" class="data row8 col4" >0.4139</td>
#       <td id="T_a6d4a_row8_col5" class="data row8 col5" >0.3604</td>
#       <td id="T_a6d4a_row8_col6" class="data row8 col6" >0.3755</td>
#     </tr>
#     <tr>
#       <th id="T_a6d4a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a6d4a_row9_col0" class="data row9 col0" >0.8963</td>
#       <td id="T_a6d4a_row9_col1" class="data row9 col1" >0.7864</td>
#       <td id="T_a6d4a_row9_col2" class="data row9 col2" >0.3169</td>
#       <td id="T_a6d4a_row9_col3" class="data row9 col3" >0.5722</td>
#       <td id="T_a6d4a_row9_col4" class="data row9 col4" >0.4079</td>
#       <td id="T_a6d4a_row9_col5" class="data row9 col5" >0.3562</td>
#       <td id="T_a6d4a_row9_col6" class="data row9 col6" >0.3749</td>
#     </tr>
#     <tr>
#       <th id="T_a6d4a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a6d4a_row10_col0" class="data row10 col0" >0.8970</td>
#       <td id="T_a6d4a_row10_col1" class="data row10 col1" >0.8007</td>
#       <td id="T_a6d4a_row10_col2" class="data row10 col2" >0.3267</td>
#       <td id="T_a6d4a_row10_col3" class="data row10 col3" >0.5767</td>
#       <td id="T_a6d4a_row10_col4" class="data row10 col4" >0.4167</td>
#       <td id="T_a6d4a_row10_col5" class="data row10 col5" >0.3649</td>
#       <td id="T_a6d4a_row10_col6" class="data row10 col6" >0.3829</td>
#     </tr>
#     <tr>
#       <th id="T_a6d4a_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_a6d4a_row11_col0" class="data row11 col0" >0.0035</td>
#       <td id="T_a6d4a_row11_col1" class="data row11 col1" >0.0128</td>
#       <td id="T_a6d4a_row11_col2" class="data row11 col2" >0.0163</td>
#       <td id="T_a6d4a_row11_col3" class="data row11 col3" >0.0300</td>
#       <td id="T_a6d4a_row11_col4" class="data row11 col4" >0.0169</td>
#       <td id="T_a6d4a_row11_col5" class="data row11 col5" >0.0181</td>
#       <td id="T_a6d4a_row11_col6" class="data row11 col6" >0.0190</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(lgbm)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=234, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
tuned_lgbm = tune_model(lgbm, optimize="AUC")
# Out:
# <style type="text/css">
# #T_4231b_row10_col0, #T_4231b_row10_col1, #T_4231b_row10_col2, #T_4231b_row10_col3, #T_4231b_row10_col4, #T_4231b_row10_col5, #T_4231b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_4231b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4231b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_4231b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_4231b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_4231b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_4231b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_4231b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_4231b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4231b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4231b_row0_col0" class="data row0 col0" >0.9001</td>
#       <td id="T_4231b_row0_col1" class="data row0 col1" >0.8087</td>
#       <td id="T_4231b_row0_col2" class="data row0 col2" >0.3077</td>
#       <td id="T_4231b_row0_col3" class="data row0 col3" >0.6135</td>
#       <td id="T_4231b_row0_col4" class="data row0 col4" >0.4098</td>
#       <td id="T_4231b_row0_col5" class="data row0 col5" >0.3618</td>
#       <td id="T_4231b_row0_col6" class="data row0 col6" >0.3876</td>
#     </tr>
#     <tr>
#       <th id="T_4231b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4231b_row1_col0" class="data row1 col0" >0.8970</td>
#       <td id="T_4231b_row1_col1" class="data row1 col1" >0.7903</td>
#       <td id="T_4231b_row1_col2" class="data row1 col2" >0.2500</td>
#       <td id="T_4231b_row1_col3" class="data row1 col3" >0.6000</td>
#       <td id="T_4231b_row1_col4" class="data row1 col4" >0.3529</td>
#       <td id="T_4231b_row1_col5" class="data row1 col5" >0.3071</td>
#       <td id="T_4231b_row1_col6" class="data row1 col6" >0.3422</td>
#     </tr>
#     <tr>
#       <th id="T_4231b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4231b_row2_col0" class="data row2 col0" >0.8956</td>
#       <td id="T_4231b_row2_col1" class="data row2 col1" >0.7916</td>
#       <td id="T_4231b_row2_col2" class="data row2 col2" >0.3179</td>
#       <td id="T_4231b_row2_col3" class="data row2 col3" >0.5628</td>
#       <td id="T_4231b_row2_col4" class="data row2 col4" >0.4063</td>
#       <td id="T_4231b_row2_col5" class="data row2 col5" >0.3539</td>
#       <td id="T_4231b_row2_col6" class="data row2 col6" >0.3713</td>
#     </tr>
#     <tr>
#       <th id="T_4231b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4231b_row3_col0" class="data row3 col0" >0.8949</td>
#       <td id="T_4231b_row3_col1" class="data row3 col1" >0.7834</td>
#       <td id="T_4231b_row3_col2" class="data row3 col2" >0.2985</td>
#       <td id="T_4231b_row3_col3" class="data row3 col3" >0.5640</td>
#       <td id="T_4231b_row3_col4" class="data row3 col4" >0.3903</td>
#       <td id="T_4231b_row3_col5" class="data row3 col5" >0.3387</td>
#       <td id="T_4231b_row3_col6" class="data row3 col6" >0.3594</td>
#     </tr>
#     <tr>
#       <th id="T_4231b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4231b_row4_col0" class="data row4 col0" >0.9008</td>
#       <td id="T_4231b_row4_col1" class="data row4 col1" >0.8196</td>
#       <td id="T_4231b_row4_col2" class="data row4 col2" >0.3169</td>
#       <td id="T_4231b_row4_col3" class="data row4 col3" >0.6168</td>
#       <td id="T_4231b_row4_col4" class="data row4 col4" >0.4187</td>
#       <td id="T_4231b_row4_col5" class="data row4 col5" >0.3705</td>
#       <td id="T_4231b_row4_col6" class="data row4 col6" >0.3952</td>
#     </tr>
#     <tr>
#       <th id="T_4231b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4231b_row5_col0" class="data row5 col0" >0.8932</td>
#       <td id="T_4231b_row5_col1" class="data row5 col1" >0.8065</td>
#       <td id="T_4231b_row5_col2" class="data row5 col2" >0.2738</td>
#       <td id="T_4231b_row5_col3" class="data row5 col3" >0.5528</td>
#       <td id="T_4231b_row5_col4" class="data row5 col4" >0.3663</td>
#       <td id="T_4231b_row5_col5" class="data row5 col5" >0.3151</td>
#       <td id="T_4231b_row5_col6" class="data row5 col6" >0.3384</td>
#     </tr>
#     <tr>
#       <th id="T_4231b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4231b_row6_col0" class="data row6 col0" >0.9025</td>
#       <td id="T_4231b_row6_col1" class="data row6 col1" >0.8057</td>
#       <td id="T_4231b_row6_col2" class="data row6 col2" >0.3169</td>
#       <td id="T_4231b_row6_col3" class="data row6 col3" >0.6358</td>
#       <td id="T_4231b_row6_col4" class="data row6 col4" >0.4230</td>
#       <td id="T_4231b_row6_col5" class="data row6 col5" >0.3762</td>
#       <td id="T_4231b_row6_col6" class="data row6 col6" >0.4036</td>
#     </tr>
#     <tr>
#       <th id="T_4231b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4231b_row7_col0" class="data row7 col0" >0.9015</td>
#       <td id="T_4231b_row7_col1" class="data row7 col1" >0.8020</td>
#       <td id="T_4231b_row7_col2" class="data row7 col2" >0.3015</td>
#       <td id="T_4231b_row7_col3" class="data row7 col3" >0.6323</td>
#       <td id="T_4231b_row7_col4" class="data row7 col4" >0.4083</td>
#       <td id="T_4231b_row7_col5" class="data row7 col5" >0.3619</td>
#       <td id="T_4231b_row7_col6" class="data row7 col6" >0.3916</td>
#     </tr>
#     <tr>
#       <th id="T_4231b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4231b_row8_col0" class="data row8 col0" >0.8956</td>
#       <td id="T_4231b_row8_col1" class="data row8 col1" >0.8066</td>
#       <td id="T_4231b_row8_col2" class="data row8 col2" >0.3077</td>
#       <td id="T_4231b_row8_col3" class="data row8 col3" >0.5682</td>
#       <td id="T_4231b_row8_col4" class="data row8 col4" >0.3992</td>
#       <td id="T_4231b_row8_col5" class="data row8 col5" >0.3475</td>
#       <td id="T_4231b_row8_col6" class="data row8 col6" >0.3672</td>
#     </tr>
#     <tr>
#       <th id="T_4231b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4231b_row9_col0" class="data row9 col0" >0.9015</td>
#       <td id="T_4231b_row9_col1" class="data row9 col1" >0.7930</td>
#       <td id="T_4231b_row9_col2" class="data row9 col2" >0.3231</td>
#       <td id="T_4231b_row9_col3" class="data row9 col3" >0.6213</td>
#       <td id="T_4231b_row9_col4" class="data row9 col4" >0.4251</td>
#       <td id="T_4231b_row9_col5" class="data row9 col5" >0.3771</td>
#       <td id="T_4231b_row9_col6" class="data row9 col6" >0.4013</td>
#     </tr>
#     <tr>
#       <th id="T_4231b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_4231b_row10_col0" class="data row10 col0" >0.8983</td>
#       <td id="T_4231b_row10_col1" class="data row10 col1" >0.8007</td>
#       <td id="T_4231b_row10_col2" class="data row10 col2" >0.3014</td>
#       <td id="T_4231b_row10_col3" class="data row10 col3" >0.5967</td>
#       <td id="T_4231b_row10_col4" class="data row10 col4" >0.4000</td>
#       <td id="T_4231b_row10_col5" class="data row10 col5" >0.3510</td>
#       <td id="T_4231b_row10_col6" class="data row10 col6" >0.3758</td>
#     </tr>
#     <tr>
#       <th id="T_4231b_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_4231b_row11_col0" class="data row11 col0" >0.0032</td>
#       <td id="T_4231b_row11_col1" class="data row11 col1" >0.0103</td>
#       <td id="T_4231b_row11_col2" class="data row11 col2" >0.0217</td>
#       <td id="T_4231b_row11_col3" class="data row11 col3" >0.0301</td>
#       <td id="T_4231b_row11_col4" class="data row11 col4" >0.0227</td>
#       <td id="T_4231b_row11_col5" class="data row11 col5" >0.0231</td>
#       <td id="T_4231b_row11_col6" class="data row11 col6" >0.0225</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(tuned_lgbm)
# Out:
# LGBMClassifier(bagging_fraction=0.5, bagging_freq=6, boosting_type='gbdt',
#                class_weight=None, colsample_bytree=1.0, feature_fraction=0.4,
#                importance_type='split', learning_rate=0.068, max_depth=-1,
#                min_child_samples=70, min_child_weight=0.001, min_split_gain=0.8,
#                n_estimators=270, n_jobs=-1, num_leaves=70, objective=None,
#                random_state=234, reg_alpha=0.2, reg_lambda=0.001, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
plot_model(tuned_lgbm, plot = 'auc')

# %%
plot_model(tuned_lgbm, plot='feature')

# %%
plot_model(tuned_lgbm, plot = 'confusion_matrix')

# %%
plot_model(tuned_lgbm, plot = 'class_report')

# %% [markdown]
# ### CatBoost Classifier

# %%
catboost = create_model("catboost")
# Out:
# <style type="text/css">
# #T_aa974_row10_col0, #T_aa974_row10_col1, #T_aa974_row10_col2, #T_aa974_row10_col3, #T_aa974_row10_col4, #T_aa974_row10_col5, #T_aa974_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_aa974">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa974_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_aa974_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_aa974_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_aa974_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_aa974_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_aa974_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_aa974_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa974_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aa974_row0_col0" class="data row0 col0" >0.8984</td>
#       <td id="T_aa974_row0_col1" class="data row0 col1" >0.8007</td>
#       <td id="T_aa974_row0_col2" class="data row0 col2" >0.3108</td>
#       <td id="T_aa974_row0_col3" class="data row0 col3" >0.5941</td>
#       <td id="T_aa974_row0_col4" class="data row0 col4" >0.4081</td>
#       <td id="T_aa974_row0_col5" class="data row0 col5" >0.3584</td>
#       <td id="T_aa974_row0_col6" class="data row0 col6" >0.3810</td>
#     </tr>
#     <tr>
#       <th id="T_aa974_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aa974_row1_col0" class="data row1 col0" >0.8994</td>
#       <td id="T_aa974_row1_col1" class="data row1 col1" >0.7942</td>
#       <td id="T_aa974_row1_col2" class="data row1 col2" >0.2809</td>
#       <td id="T_aa974_row1_col3" class="data row1 col3" >0.6149</td>
#       <td id="T_aa974_row1_col4" class="data row1 col4" >0.3856</td>
#       <td id="T_aa974_row1_col5" class="data row1 col5" >0.3390</td>
#       <td id="T_aa974_row1_col6" class="data row1 col6" >0.3701</td>
#     </tr>
#     <tr>
#       <th id="T_aa974_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aa974_row2_col0" class="data row2 col0" >0.8949</td>
#       <td id="T_aa974_row2_col1" class="data row2 col1" >0.7858</td>
#       <td id="T_aa974_row2_col2" class="data row2 col2" >0.3241</td>
#       <td id="T_aa974_row2_col3" class="data row2 col3" >0.5556</td>
#       <td id="T_aa974_row2_col4" class="data row2 col4" >0.4094</td>
#       <td id="T_aa974_row2_col5" class="data row2 col5" >0.3560</td>
#       <td id="T_aa974_row2_col6" class="data row2 col6" >0.3717</td>
#     </tr>
#     <tr>
#       <th id="T_aa974_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aa974_row3_col0" class="data row3 col0" >0.8921</td>
#       <td id="T_aa974_row3_col1" class="data row3 col1" >0.7848</td>
#       <td id="T_aa974_row3_col2" class="data row3 col2" >0.2769</td>
#       <td id="T_aa974_row3_col3" class="data row3 col3" >0.5422</td>
#       <td id="T_aa974_row3_col4" class="data row3 col4" >0.3666</td>
#       <td id="T_aa974_row3_col5" class="data row3 col5" >0.3143</td>
#       <td id="T_aa974_row3_col6" class="data row3 col6" >0.3356</td>
#     </tr>
#     <tr>
#       <th id="T_aa974_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aa974_row4_col0" class="data row4 col0" >0.9025</td>
#       <td id="T_aa974_row4_col1" class="data row4 col1" >0.8187</td>
#       <td id="T_aa974_row4_col2" class="data row4 col2" >0.3415</td>
#       <td id="T_aa974_row4_col3" class="data row4 col3" >0.6236</td>
#       <td id="T_aa974_row4_col4" class="data row4 col4" >0.4414</td>
#       <td id="T_aa974_row4_col5" class="data row4 col5" >0.3929</td>
#       <td id="T_aa974_row4_col6" class="data row4 col6" >0.4144</td>
#     </tr>
#     <tr>
#       <th id="T_aa974_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aa974_row5_col0" class="data row5 col0" >0.8949</td>
#       <td id="T_aa974_row5_col1" class="data row5 col1" >0.7977</td>
#       <td id="T_aa974_row5_col2" class="data row5 col2" >0.3138</td>
#       <td id="T_aa974_row5_col3" class="data row5 col3" >0.5604</td>
#       <td id="T_aa974_row5_col4" class="data row5 col4" >0.4024</td>
#       <td id="T_aa974_row5_col5" class="data row5 col5" >0.3497</td>
#       <td id="T_aa974_row5_col6" class="data row5 col6" >0.3675</td>
#     </tr>
#     <tr>
#       <th id="T_aa974_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aa974_row6_col0" class="data row6 col0" >0.9001</td>
#       <td id="T_aa974_row6_col1" class="data row6 col1" >0.7949</td>
#       <td id="T_aa974_row6_col2" class="data row6 col2" >0.2985</td>
#       <td id="T_aa974_row6_col3" class="data row6 col3" >0.6178</td>
#       <td id="T_aa974_row6_col4" class="data row6 col4" >0.4025</td>
#       <td id="T_aa974_row6_col5" class="data row6 col5" >0.3551</td>
#       <td id="T_aa974_row6_col6" class="data row6 col6" >0.3833</td>
#     </tr>
#     <tr>
#       <th id="T_aa974_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aa974_row7_col0" class="data row7 col0" >0.8928</td>
#       <td id="T_aa974_row7_col1" class="data row7 col1" >0.7910</td>
#       <td id="T_aa974_row7_col2" class="data row7 col2" >0.2615</td>
#       <td id="T_aa974_row7_col3" class="data row7 col3" >0.5519</td>
#       <td id="T_aa974_row7_col4" class="data row7 col4" >0.3549</td>
#       <td id="T_aa974_row7_col5" class="data row7 col5" >0.3045</td>
#       <td id="T_aa974_row7_col6" class="data row7 col6" >0.3299</td>
#     </tr>
#     <tr>
#       <th id="T_aa974_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aa974_row8_col0" class="data row8 col0" >0.8977</td>
#       <td id="T_aa974_row8_col1" class="data row8 col1" >0.8090</td>
#       <td id="T_aa974_row8_col2" class="data row8 col2" >0.3231</td>
#       <td id="T_aa974_row8_col3" class="data row8 col3" >0.5833</td>
#       <td id="T_aa974_row8_col4" class="data row8 col4" >0.4158</td>
#       <td id="T_aa974_row8_col5" class="data row8 col5" >0.3648</td>
#       <td id="T_aa974_row8_col6" class="data row8 col6" >0.3840</td>
#     </tr>
#     <tr>
#       <th id="T_aa974_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aa974_row9_col0" class="data row9 col0" >0.9001</td>
#       <td id="T_aa974_row9_col1" class="data row9 col1" >0.7856</td>
#       <td id="T_aa974_row9_col2" class="data row9 col2" >0.3138</td>
#       <td id="T_aa974_row9_col3" class="data row9 col3" >0.6108</td>
#       <td id="T_aa974_row9_col4" class="data row9 col4" >0.4146</td>
#       <td id="T_aa974_row9_col5" class="data row9 col5" >0.3661</td>
#       <td id="T_aa974_row9_col6" class="data row9 col6" >0.3905</td>
#     </tr>
#     <tr>
#       <th id="T_aa974_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_aa974_row10_col0" class="data row10 col0" >0.8973</td>
#       <td id="T_aa974_row10_col1" class="data row10 col1" >0.7962</td>
#       <td id="T_aa974_row10_col2" class="data row10 col2" >0.3045</td>
#       <td id="T_aa974_row10_col3" class="data row10 col3" >0.5855</td>
#       <td id="T_aa974_row10_col4" class="data row10 col4" >0.4001</td>
#       <td id="T_aa974_row10_col5" class="data row10 col5" >0.3501</td>
#       <td id="T_aa974_row10_col6" class="data row10 col6" >0.3728</td>
#     </tr>
#     <tr>
#       <th id="T_aa974_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_aa974_row11_col0" class="data row11 col0" >0.0033</td>
#       <td id="T_aa974_row11_col1" class="data row11 col1" >0.0104</td>
#       <td id="T_aa974_row11_col2" class="data row11 col2" >0.0235</td>
#       <td id="T_aa974_row11_col3" class="data row11 col3" >0.0293</td>
#       <td id="T_aa974_row11_col4" class="data row11 col4" >0.0239</td>
#       <td id="T_aa974_row11_col5" class="data row11 col5" >0.0243</td>
#       <td id="T_aa974_row11_col6" class="data row11 col6" >0.0237</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(catboost, plot = 'auc')

# %%
plot_model(catboost, plot='feature')

# %%
plot_model(catboost, plot = 'confusion_matrix')

# %% [markdown]
# ### Logistic Regression

# %%
lr = create_model("lr")
# Out:
# <style type="text/css">
# #T_3d2f5_row10_col0, #T_3d2f5_row10_col1, #T_3d2f5_row10_col2, #T_3d2f5_row10_col3, #T_3d2f5_row10_col4, #T_3d2f5_row10_col5, #T_3d2f5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3d2f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d2f5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3d2f5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3d2f5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3d2f5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3d2f5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3d2f5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3d2f5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d2f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d2f5_row0_col0" class="data row0 col0" >0.8315</td>
#       <td id="T_3d2f5_row0_col1" class="data row0 col1" >0.7995</td>
#       <td id="T_3d2f5_row0_col2" class="data row0 col2" >0.6462</td>
#       <td id="T_3d2f5_row0_col3" class="data row0 col3" >0.3614</td>
#       <td id="T_3d2f5_row0_col4" class="data row0 col4" >0.4636</td>
#       <td id="T_3d2f5_row0_col5" class="data row0 col5" >0.3729</td>
#       <td id="T_3d2f5_row0_col6" class="data row0 col6" >0.3951</td>
#     </tr>
#     <tr>
#       <th id="T_3d2f5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d2f5_row1_col0" class="data row1 col0" >0.8123</td>
#       <td id="T_3d2f5_row1_col1" class="data row1 col1" >0.7691</td>
#       <td id="T_3d2f5_row1_col2" class="data row1 col2" >0.6173</td>
#       <td id="T_3d2f5_row1_col3" class="data row1 col3" >0.3241</td>
#       <td id="T_3d2f5_row1_col4" class="data row1 col4" >0.4251</td>
#       <td id="T_3d2f5_row1_col5" class="data row1 col5" >0.3257</td>
#       <td id="T_3d2f5_row1_col6" class="data row1 col6" >0.3499</td>
#     </tr>
#     <tr>
#       <th id="T_3d2f5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d2f5_row2_col0" class="data row2 col0" >0.8130</td>
#       <td id="T_3d2f5_row2_col1" class="data row2 col1" >0.7886</td>
#       <td id="T_3d2f5_row2_col2" class="data row2 col2" >0.6451</td>
#       <td id="T_3d2f5_row2_col3" class="data row2 col3" >0.3302</td>
#       <td id="T_3d2f5_row2_col4" class="data row2 col4" >0.4368</td>
#       <td id="T_3d2f5_row2_col5" class="data row2 col5" >0.3384</td>
#       <td id="T_3d2f5_row2_col6" class="data row2 col6" >0.3658</td>
#     </tr>
#     <tr>
#       <th id="T_3d2f5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d2f5_row3_col0" class="data row3 col0" >0.8030</td>
#       <td id="T_3d2f5_row3_col1" class="data row3 col1" >0.7712</td>
#       <td id="T_3d2f5_row3_col2" class="data row3 col2" >0.5908</td>
#       <td id="T_3d2f5_row3_col3" class="data row3 col3" >0.3062</td>
#       <td id="T_3d2f5_row3_col4" class="data row3 col4" >0.4034</td>
#       <td id="T_3d2f5_row3_col5" class="data row3 col5" >0.2993</td>
#       <td id="T_3d2f5_row3_col6" class="data row3 col6" >0.3225</td>
#     </tr>
#     <tr>
#       <th id="T_3d2f5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d2f5_row4_col0" class="data row4 col0" >0.8456</td>
#       <td id="T_3d2f5_row4_col1" class="data row4 col1" >0.8227</td>
#       <td id="T_3d2f5_row4_col2" class="data row4 col2" >0.6800</td>
#       <td id="T_3d2f5_row4_col3" class="data row4 col3" >0.3932</td>
#       <td id="T_3d2f5_row4_col4" class="data row4 col4" >0.4983</td>
#       <td id="T_3d2f5_row4_col5" class="data row4 col5" >0.4147</td>
#       <td id="T_3d2f5_row4_col6" class="data row4 col6" >0.4364</td>
#     </tr>
#     <tr>
#       <th id="T_3d2f5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3d2f5_row5_col0" class="data row5 col0" >0.8280</td>
#       <td id="T_3d2f5_row5_col1" class="data row5 col1" >0.7933</td>
#       <td id="T_3d2f5_row5_col2" class="data row5 col2" >0.6431</td>
#       <td id="T_3d2f5_row5_col3" class="data row5 col3" >0.3548</td>
#       <td id="T_3d2f5_row5_col4" class="data row5 col4" >0.4573</td>
#       <td id="T_3d2f5_row5_col5" class="data row5 col5" >0.3651</td>
#       <td id="T_3d2f5_row5_col6" class="data row5 col6" >0.3879</td>
#     </tr>
#     <tr>
#       <th id="T_3d2f5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3d2f5_row6_col0" class="data row6 col0" >0.8248</td>
#       <td id="T_3d2f5_row6_col1" class="data row6 col1" >0.7841</td>
#       <td id="T_3d2f5_row6_col2" class="data row6 col2" >0.6400</td>
#       <td id="T_3d2f5_row6_col3" class="data row6 col3" >0.3490</td>
#       <td id="T_3d2f5_row6_col4" class="data row6 col4" >0.4517</td>
#       <td id="T_3d2f5_row6_col5" class="data row6 col5" >0.3580</td>
#       <td id="T_3d2f5_row6_col6" class="data row6 col6" >0.3814</td>
#     </tr>
#     <tr>
#       <th id="T_3d2f5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3d2f5_row7_col0" class="data row7 col0" >0.8283</td>
#       <td id="T_3d2f5_row7_col1" class="data row7 col1" >0.7993</td>
#       <td id="T_3d2f5_row7_col2" class="data row7 col2" >0.6246</td>
#       <td id="T_3d2f5_row7_col3" class="data row7 col3" >0.3524</td>
#       <td id="T_3d2f5_row7_col4" class="data row7 col4" >0.4506</td>
#       <td id="T_3d2f5_row7_col5" class="data row7 col5" >0.3581</td>
#       <td id="T_3d2f5_row7_col6" class="data row7 col6" >0.3787</td>
#     </tr>
#     <tr>
#       <th id="T_3d2f5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3d2f5_row8_col0" class="data row8 col0" >0.8266</td>
#       <td id="T_3d2f5_row8_col1" class="data row8 col1" >0.8056</td>
#       <td id="T_3d2f5_row8_col2" class="data row8 col2" >0.6677</td>
#       <td id="T_3d2f5_row8_col3" class="data row8 col3" >0.3563</td>
#       <td id="T_3d2f5_row8_col4" class="data row8 col4" >0.4647</td>
#       <td id="T_3d2f5_row8_col5" class="data row8 col5" >0.3724</td>
#       <td id="T_3d2f5_row8_col6" class="data row8 col6" >0.3986</td>
#     </tr>
#     <tr>
#       <th id="T_3d2f5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3d2f5_row9_col0" class="data row9 col0" >0.8179</td>
#       <td id="T_3d2f5_row9_col1" class="data row9 col1" >0.7697</td>
#       <td id="T_3d2f5_row9_col2" class="data row9 col2" >0.5969</td>
#       <td id="T_3d2f5_row9_col3" class="data row9 col3" >0.3299</td>
#       <td id="T_3d2f5_row9_col4" class="data row9 col4" >0.4250</td>
#       <td id="T_3d2f5_row9_col5" class="data row9 col5" >0.3273</td>
#       <td id="T_3d2f5_row9_col6" class="data row9 col6" >0.3476</td>
#     </tr>
#     <tr>
#       <th id="T_3d2f5_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3d2f5_row10_col0" class="data row10 col0" >0.8231</td>
#       <td id="T_3d2f5_row10_col1" class="data row10 col1" >0.7903</td>
#       <td id="T_3d2f5_row10_col2" class="data row10 col2" >0.6352</td>
#       <td id="T_3d2f5_row10_col3" class="data row10 col3" >0.3458</td>
#       <td id="T_3d2f5_row10_col4" class="data row10 col4" >0.4476</td>
#       <td id="T_3d2f5_row10_col5" class="data row10 col5" >0.3532</td>
#       <td id="T_3d2f5_row10_col6" class="data row10 col6" >0.3764</td>
#     </tr>
#     <tr>
#       <th id="T_3d2f5_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_3d2f5_row11_col0" class="data row11 col0" >0.0114</td>
#       <td id="T_3d2f5_row11_col1" class="data row11 col1" >0.0165</td>
#       <td id="T_3d2f5_row11_col2" class="data row11 col2" >0.0269</td>
#       <td id="T_3d2f5_row11_col3" class="data row11 col3" >0.0230</td>
#       <td id="T_3d2f5_row11_col4" class="data row11 col4" >0.0252</td>
#       <td id="T_3d2f5_row11_col5" class="data row11 col5" >0.0305</td>
#       <td id="T_3d2f5_row11_col6" class="data row11 col6" >0.0303</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(lr, plot = 'auc')

# %%
plot_model(lr, plot='feature')

# %%
plot_model(catboost, plot = 'confusion_matrix')
